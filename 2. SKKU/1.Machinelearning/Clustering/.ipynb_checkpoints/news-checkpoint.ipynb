# %%
# %matplotlib inline
import nltk
import numpy as np
import pandas as pd
import re
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans
from sklearn.manifold import MDS
import matplotlib.pyplot as plt

# %%
titles = open('news_title.txt').read().split('\n')
synopses = open('news_keyword.txt').read().split('\n')
synopses = synopses[:300]
titles = titles[:300]
print(len(titles)) # output = 100
print(len(synopses)) # output = 100
# Out:
# 300
# 300

# %%
stemmer = SnowballStemmer("english")

def tokenize_stem(text):
    tokens = [word.lower() for sent in nltk.sent_tokenize(text)
                    for word in nltk.word_tokenize(sent)]
    final_tokens = []
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            final_tokens.append(token)

    stems = [stemmer.stem(t) for t in final_tokens]
    return stems

# %%
stopwords = nltk.corpus.stopwords.words("english")

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=200000, max_df=0.8, min_df=0.1)
tfidf_matrix = tfidf_vectorizer.fit_transform(synopses)
print(tfidf_matrix.shape) # output = (100, 548)
terms = tfidf_vectorizer.get_feature_names()
print(terms)
# Out:
# (300, 16)
# ['가격', '강화', '관계자', '기간', '기관', '기준', '노력', '대상', '방식', '상황', '운영', '이날', '정책', '진행', '확인', '활동']

# %%
km = KMeans(n_clusters = 5)
km.fit(tfidf_matrix) # K-means clustering 적용
clusters = km.labels_.tolist() # 리스트화
print(clusters)
len(clusters)
# Out:
# [4, 4, 2, 3, 2, 2, 2, 4, 4, 0, 2, 0, 2, 2, 0, 0, 2, 1, 4, 1, 0, 2, 3, 2, 2, 4, 1, 3, 1, 2, 3, 0, 2, 3, 1, 2, 0, 1, 2, 4, 4, 4, 2, 1, 1, 2, 1, 3, 3, 4, 2, 4, 3, 3, 2, 2, 3, 2, 3, 2, 0, 0, 3, 2, 2, 3, 1, 2, 4, 2, 2, 4, 3, 2, 3, 1, 2, 4, 2, 2, 2, 2, 0, 4, 0, 4, 0, 1, 2, 2, 1, 2, 3, 3, 2, 2, 2, 2, 2, 4, 0, 2, 2, 0, 1, 1, 2, 2, 1, 2, 1, 2, 2, 2, 2, 1, 3, 2, 2, 1, 2, 2, 2, 1, 2, 1, 2, 4, 2, 0, 1, 2, 0, 2, 0, 1, 2, 2, 2, 2, 2, 3, 2, 1, 3, 1, 4, 4, 4, 3, 1, 2, 2, 2, 3, 2, 1, 2, 2, 3, 3, 2, 0, 2, 2, 3, 1, 2, 2, 4, 3, 0, 1, 3, 2, 2, 2, 3, 3, 4, 4, 2, 4, 2, 2, 4, 2, 3, 2, 2, 1, 4, 1, 2, 1, 2, 2, 0, 4, 0, 4, 2, 2, 2, 2, 4, 3, 2, 0, 4, 2, 2, 0, 0, 3, 2, 1, 0, 1, 1, 3, 0, 3, 2, 3, 0, 2, 2, 0, 2, 2, 2, 0, 3, 2, 1, 1, 2, 1, 0, 2, 2, 4, 2, 2, 2, 3, 2, 1, 2, 2, 1, 2, 2, 4, 3, 3, 1, 4, 2, 0, 3, 2, 2, 4, 2, 4, 3, 2, 2, 2, 0, 2, 4, 2, 2, 3, 2, 1, 2, 2, 2, 0, 0, 1, 3, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2]
# 300

# %%
films = {'title': titles, 'synopsis': synopses, 'cluster': clusters}
frame = pd.DataFrame(films, index=clusters, columns=['title', 'cluster'])
frame['cluster'].value_counts() # 각 클러스터의 영화 개수 출력
# Out:
# 2    141
# 1     44
# 3     43
# 4     37
# 0     35
# Name: cluster, dtype: int64

# %%
print("Top terms per cluster:\n\n")
order_centroids = km.cluster_centers_.argsort()[:, ::-1]
for i in range(5):
    print("Cluster %d words:" % i, end='')
    for j in range(5):
        print(terms[order_centroids[i][j]], end=',')
    print('\n')
    print("Cluster %d titles:" % i, end='')
    for title in frame.loc[i]['title'].values.tolist():
        print(' %s,' % title, end='')
    
#
# Cluster 4 words:기준,대상,기간,관계자,정책,
#
# Cluster 4 titles: 뉴욕증시 연준 정책 금리 결정 강세 다우 , 친환경차 122대 고속 질주 1만 , 부산항 장기화 유치 크루즈 성과 관광객 , 국민 10명 8명 에너지 전환 의향 , 누적수익률 투증 6.8% 포트폴리오 , 49개 학교 초고압 송전선로 노출 규정을 , 코스닥 6일 핫데뷔 티슈진 시총 2조 , 3분기 해외여행 7.8조 역대 최대 , 연내 서울 재개발 재건축 100가구 일반 분양 , 마마 호화 엑소 방탄소년단 라인업 트와이스 워너원 , 성인 로시 흡연율 대표 한국 공부 환경 , 광주도시철도공사 복지포인트 통상 임금 판결 , 씨티씨바이오 연말 영업흑자 달성 수출 본격화 흑자전환 , 전남문화관광재단 마구잡이 인사 말썽 , 공공기관 내년 채용 지역할당 지역인재 의무화 , 다국적 기업 조세회피 연간 77조 손실 심화 , 가계통신비 논의 조충현 사단법인 이동통신 협회 , 전세기 거리두 아시아나항공 비거리 경쟁력 , 내년 울산대 문제낸 2명 연세대 정원 제재 , 1위 빅데이터 신성장동력 코스닥 상장 , 파견법 말썽 8명 당장 일자리 선택 , 포항 주택 2.0 파손 여진 공포 , 2018학년도 1학기 국가장학금 접수 시작 , 한미 안보 동맹 무기도입 구매 , 장나라 손호준 고백부부 혼자 시간대 , 선호 지역 강남 다주택 무주택자 적어 , 경기도내 주택시장 양극화 사람 집주인 , 한국지엠 르노삼성 생산 중단 치열 고개 넘버 , 한화건설 마곡지구 면적 10분 김포 꿈에그린 유로메트로 , 원자력연구원 이동형 아프리카 단층촬영장치 , 1년 분양가 신길뉴타운 수직상승세 힐스테이트 1476가구 , 재개발 지역 조합원 부담 비례율 분담금 , 화물차 추돌사고 1506건 위험 반사띠부착 , 코스닥 800선 기대감 우려감 거품 공존 , 현장실습 이군 법개정 고교 , 금융당국 합병안 수주 성동조선 청산 , 촉진 위헌 소지 기업소득환류세제 ,

# %%
#set up colors per clusters using a dict
cluster_colors = {0: 'red', 1: 'blue', 2: 'green', 3: 'purple', 4: 'orange'}

#set up cluster names using a dict
cluster_names = {0: 'Kill, Solider, Army',
                 1: 'Sing, Love, Relationship',
                 2: 'Car, Drive, Train',
                 3: 'Family, Home, Brother',
                 4: 'Marry, Woman, Friend'}

# %%
dist = 1 - cosine_similarity(tfidf_matrix) # distance equation
mds = MDS(n_components=2, dissimilarity = 'precomputed')
Z = mds.fit_transform(dist) # 2차원으로 축소
xs, ys = Z[:, 0], Z[:, 1] # 시각화를 위해 저장해둔

# %%
df = pd.DataFrame(dict(x = xs, y = ys, label=clusters, title=titles))
groups = df.groupby('label')

# %%
fig, ax = plt.subplots(figsize=(17, 12)) # set size

for idx, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=15, label=cluster_names[idx], color=cluster_colors[idx])
    
ax.legend(numpoints=1) #show legend with only 1 point
for i in range(len(df)):
    ax.text(df.ix[i]['x'], df.ix[i]['y'], df.ix[i]['title'], size = 11)
plt.show()
# Out:
# C:\Users\user19\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
