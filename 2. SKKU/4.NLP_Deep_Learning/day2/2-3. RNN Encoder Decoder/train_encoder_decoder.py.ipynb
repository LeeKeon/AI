# %%
# -*- coding: utf-8 -*-

import os
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

import tensorflow as tf
import numpy as np
import time

from encoder_decoder_model import Model
from data_loader import text_data
# Out:
# /etc/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def initialize_session():
    config = tf.ConfigProto()
    #config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    return tf.Session(config=config)

##################################################
max_len = 40            # sequence 단어 수 제한
BATCH_SIZE = 20         # 배치 사이즈 - 1이 아니면 입력 데이터 구성이 어려움
emb_dim = 64            # 단어 embedding dimension
hidden_dim = 128        # RNN hidden dim
learning_rate = 0.005   # Learning rate
use_clip = True         # Gradient clipping 쓸지 여부
##################################################

END_TOKEN = "<eos>"
data = text_data("./dataset/ptb", max_len=max_len, end_token=END_TOKEN)
model = Model(emb_dim=emb_dim, hidden_dim=hidden_dim, vocab_size=data.vocab_size,
              use_clip=True, learning_rate=learning_rate, end_token=data.w2idx[END_TOKEN])

sess = initialize_session()
sess.run(tf.global_variables_initializer())


def sample_test(test_input=""):
    # test_input = raw_input("test text: ") # input("test text: ") for python 2, 3
    words = test_input.split()
    input_x = np.zeros((1, max_len), dtype=np.int32)
    for i, word in enumerate(words):
        if i == max_len:
            break
        input_x[0][i] = data.w2idx[word]

    input_x_len = [i+1]
    output = sess.run(model.output, feed_dict={model.x: input_x, model.x_len: input_x_len})
    line = " ".join([data.idx2w[o] for o in output[0]])
    print(line)

def test_model():
    num_it = int(len(data.test_ids) / BATCH_SIZE)
    test_loss, test_cnt = 0, 0

    for _ in range(num_it):
        test_ids, length = data.get_test(BATCH_SIZE)
        loss = sess.run(model.loss, feed_dict={model.x: test_ids, model.x_len: length})

        test_loss += loss
        test_cnt += 1
    print("test loss: {:.3f}".format(test_loss / test_cnt))

avg_loss, it_cnt = 0, 0
it_log, it_test, it_save, it_sample = 10, 1500, 1500, 100
start_time = time.time()

for it in range(0, 10000):
    train_ids, length = data.get_train(BATCH_SIZE)
    loss, _, batch_max_len_ = sess.run([model.loss, model.update, model.batch_max_len],
                       feed_dict={model.x: train_ids, model.x_len: length})
    # Can get text embedding
    # text_vector = sess.run(model.enc_states, feed_dict={model.x: train_ids, model.x_len: length})
    print('batch_max_len', batch_max_len_)
    avg_loss += loss
    it_cnt += 1

    if it % it_log == 0:
        print(" it: {:4d} | loss: {:.3f} - {:.2f}s".format(it, avg_loss / it_cnt, time.time() - start_time))
        avg_loss, it_cnt = 0, 0

    if it % it_test == 0 and it > 0:
        test_model()
    if it % it_save == 0 and it > 0:
        model.save(sess)
    if it % it_sample == 0 and it > 0:
        sample_test(" there is no asbestos in our products now ")

#sess.close()
# Out:
# batch_max_len 34
#  it:    0 | loss: 9.210 - 0.51s
# batch_max_len 40
# batch_max_len 33
# batch_max_len 35
# batch_max_len 34
# batch_max_len 40
# batch_max_len 40
# batch_max_len 33
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:   10 | loss: 8.110 - 1.07s
# batch_max_len 40
# batch_max_len 34
# batch_max_len 40
# batch_max_len 40
# batch_max_len 37
# batch_max_len 35
# batch_max_len 40
# batch_max_len 39
# batch_max_len 31
# batch_max_len 40
#  it:   20 | loss: 7.597 - 1.67s
# batch_max_len 31
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
# batch_max_len 37
# batch_max_len 40
# batch_max_len 40
# batch_max_len 39
# batch_max_len 39
# batch_max_len 40
#  it:   30 | loss: 7.470 - 2.23s
# batch_max_len 36
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 36
# batch_max_len 35
# batch_max_len 38
# batch_max_len 31
#  it:   40 | loss: 7.128 - 2.78s
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 37
# batch_max_len 40
# batch_max_len 40
# batch_max_len 37
# batch_max_len 35
# batch_max_len 40
# batch_max_len 40
#  it:   50 | loss: 6.800 - 3.38s
# batch_max_len 35
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 35
# batch_max_len 38
# batch_max_len 40
# batch_max_len 37
# batch_max_len 36
# batch_max_len 36
#  it:   60 | loss: 6.471 - 3.94s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 33
# batch_max_len 40
# batch_max_len 40
# batch_max_len 36
# batch_max_len 40
# batch_max_len 40
#  it:   70 | loss: 6.117 - 4.50s
# batch_max_len 40
# batch_max_len 31
# batch_max_len 34
# batch_max_len 33
# batch_max_len 40
# batch_max_len 32
# batch_max_len 30
# batch_max_len 34
# batch_max_len 40
# batch_max_len 38
#  it:   80 | loss: 6.292 - 5.01s
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 33
# batch_max_len 40
# batch_max_len 40
# batch_max_len 37
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:   90 | loss: 6.042 - 5.58s
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 31
# batch_max_len 40
# batch_max_len 35
# batch_max_len 25
#  it:  100 | loss: 5.964 - 6.15s
# the <unk> the N <unk> N N the
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 27
# batch_max_len 40
# batch_max_len 40
# batch_max_len 35
# batch_max_len 36
#  it:  110 | loss: 5.770 - 6.80s
# batch_max_len 40
# batch_max_len 36
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
# batch_max_len 40
#  it:  120 | loss: 5.710 - 7.48s
# batch_max_len 36
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 28
# batch_max_len 40
# batch_max_len 37
# batch_max_len 33
#  it:  130 | loss: 5.549 - 8.10s
# batch_max_len 33
# batch_max_len 39
# batch_max_len 32
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
# batch_max_len 35
# batch_max_len 37
# batch_max_len 34
# batch_max_len 40
#  it:  140 | loss: 5.328 - 8.69s
# batch_max_len 36
# batch_max_len 27
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 31
# batch_max_len 40
#  it:  150 | loss: 5.266 - 9.25s
# batch_max_len 30
# batch_max_len 25
# batch_max_len 40
# batch_max_len 32
# batch_max_len 40
# batch_max_len 37
# batch_max_len 40
# batch_max_len 37
# batch_max_len 35
# batch_max_len 39
#  it:  160 | loss: 4.970 - 9.81s
# batch_max_len 40
# batch_max_len 33
# batch_max_len 32
# batch_max_len 40
# batch_max_len 40
# batch_max_len 35
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
#  it:  170 | loss: 4.781 - 10.40s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 32
# batch_max_len 40
# batch_max_len 32
# batch_max_len 36
# batch_max_len 37
# batch_max_len 26
#  it:  180 | loss: 4.469 - 11.00s
# batch_max_len 33
# batch_max_len 33
# batch_max_len 38
# batch_max_len 34
# batch_max_len 35
# batch_max_len 40
# batch_max_len 34
# batch_max_len 36
# batch_max_len 33
# batch_max_len 40
#  it:  190 | loss: 4.745 - 11.57s
# batch_max_len 36
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 34
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  200 | loss: 4.472 - 12.15s
# mr. is it profit in its from sales
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 37
# batch_max_len 26
# batch_max_len 33
# batch_max_len 40
#  it:  210 | loss: 4.230 - 12.69s
# batch_max_len 39
# batch_max_len 31
# batch_max_len 39
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
# batch_max_len 36
# batch_max_len 33
#  it:  220 | loss: 4.250 - 13.24s
# batch_max_len 40
# batch_max_len 37
# batch_max_len 40
# batch_max_len 40
# batch_max_len 39
# batch_max_len 28
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  230 | loss: 4.198 - 13.80s
# batch_max_len 40
# batch_max_len 35
# batch_max_len 40
# batch_max_len 37
# batch_max_len 29
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
#  it:  240 | loss: 3.993 - 14.34s
# batch_max_len 40
# batch_max_len 37
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
#  it:  250 | loss: 3.952 - 14.92s
# batch_max_len 31
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 28
# batch_max_len 24
#  it:  260 | loss: 4.096 - 15.45s
# batch_max_len 39
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 37
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  270 | loss: 3.905 - 16.03s
# batch_max_len 33
# batch_max_len 37
# batch_max_len 39
# batch_max_len 27
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 39
# batch_max_len 39
# batch_max_len 40
#  it:  280 | loss: 3.848 - 16.56s
# batch_max_len 32
# batch_max_len 40
# batch_max_len 40
# batch_max_len 35
# batch_max_len 38
# batch_max_len 26
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  290 | loss: 3.681 - 17.12s
# batch_max_len 28
# batch_max_len 33
# batch_max_len 38
# batch_max_len 33
# batch_max_len 33
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  300 | loss: 3.719 - 17.66s
# there is no leader in use business i
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 33
# batch_max_len 36
# batch_max_len 36
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  310 | loss: 3.481 - 18.25s
# batch_max_len 32
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 39
# batch_max_len 39
# batch_max_len 39
#  it:  320 | loss: 3.219 - 18.80s
# batch_max_len 24
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 37
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
#  it:  330 | loss: 3.225 - 19.36s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 33
# batch_max_len 36
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
# batch_max_len 34
#  it:  340 | loss: 3.230 - 19.89s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 29
# batch_max_len 29
# batch_max_len 29
# batch_max_len 36
# batch_max_len 40
# batch_max_len 35
# batch_max_len 36
#  it:  350 | loss: 2.879 - 20.39s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 37
# batch_max_len 35
# batch_max_len 33
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 37
#  it:  360 | loss: 3.171 - 20.95s
# batch_max_len 31
# batch_max_len 30
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 35
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 32
#  it:  370 | loss: 2.884 - 21.47s
# batch_max_len 40
# batch_max_len 39
# batch_max_len 35
# batch_max_len 40
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 34
# batch_max_len 40
# batch_max_len 36
#  it:  380 | loss: 2.733 - 22.06s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 35
# batch_max_len 36
# batch_max_len 39
# batch_max_len 34
# batch_max_len 31
# batch_max_len 38
# batch_max_len 30
# batch_max_len 40
#  it:  390 | loss: 2.953 - 22.64s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 31
# batch_max_len 35
# batch_max_len 36
# batch_max_len 36
#  it:  400 | loss: 2.777 - 23.19s
# there is no itself in our products now
# batch_max_len 36
# batch_max_len 38
# batch_max_len 36
# batch_max_len 35
# batch_max_len 40
# batch_max_len 33
# batch_max_len 40
# batch_max_len 36
# batch_max_len 36
# batch_max_len 32
#  it:  410 | loss: 2.965 - 23.77s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 35
# batch_max_len 33
#  it:  420 | loss: 2.664 - 24.38s
# batch_max_len 30
# batch_max_len 33
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  430 | loss: 2.581 - 24.97s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  440 | loss: 2.750 - 25.56s
# batch_max_len 32
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 30
# batch_max_len 40
# batch_max_len 34
#  it:  450 | loss: 2.599 - 26.12s
# batch_max_len 38
# batch_max_len 40
# batch_max_len 35
# batch_max_len 40
# batch_max_len 40
# batch_max_len 32
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  460 | loss: 2.823 - 26.67s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 39
# batch_max_len 36
# batch_max_len 40
# batch_max_len 40
#  it:  470 | loss: 2.515 - 27.25s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 30
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
# batch_max_len 35
# batch_max_len 32
# batch_max_len 38
#  it:  480 | loss: 2.431 - 27.79s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 28
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 28
# batch_max_len 39
# batch_max_len 40
# batch_max_len 35
#  it:  490 | loss: 2.148 - 28.35s
# batch_max_len 40
# batch_max_len 33
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 33
# batch_max_len 31
# batch_max_len 30
# batch_max_len 29
# batch_max_len 36
#  it:  500 | loss: 2.414 - 28.87s
# there is no profit in our products now
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 30
# batch_max_len 40
# batch_max_len 36
# batch_max_len 39
# batch_max_len 39
# batch_max_len 32
#  it:  510 | loss: 2.390 - 29.41s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 33
# batch_max_len 40
# batch_max_len 32
# batch_max_len 29
# batch_max_len 40
# batch_max_len 40
# batch_max_len 33
# batch_max_len 40
#  it:  520 | loss: 2.181 - 29.96s
# batch_max_len 32
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
#  it:  530 | loss: 2.222 - 30.57s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 36
# batch_max_len 40
# batch_max_len 40
# batch_max_len 33
# batch_max_len 40
#  it:  540 | loss: 2.229 - 31.13s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
# batch_max_len 27
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
#  it:  550 | loss: 1.961 - 31.68s
# batch_max_len 29
# batch_max_len 38
# batch_max_len 40
# batch_max_len 34
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 33
# batch_max_len 39
#  it:  560 | loss: 1.981 - 32.20s
# batch_max_len 36
# batch_max_len 40
# batch_max_len 35
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
#  it:  570 | loss: 1.890 - 32.78s
# batch_max_len 38
# batch_max_len 35
# batch_max_len 40
# batch_max_len 31
# batch_max_len 35
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 31
#  it:  580 | loss: 2.131 - 33.32s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 37
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
#  it:  590 | loss: 2.017 - 33.92s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 39
# batch_max_len 34
# batch_max_len 39
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
#  it:  600 | loss: 1.800 - 34.46s
# there is no kidder in our products now
# batch_max_len 32
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 37
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  610 | loss: 1.946 - 35.05s
# batch_max_len 37
# batch_max_len 40
# batch_max_len 34
# batch_max_len 40
# batch_max_len 33
# batch_max_len 35
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  620 | loss: 1.642 - 35.62s
# batch_max_len 37
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 33
# batch_max_len 40
# batch_max_len 40
# batch_max_len 31
# batch_max_len 32
# batch_max_len 40
#  it:  630 | loss: 1.801 - 36.23s
# batch_max_len 39
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  640 | loss: 1.558 - 36.82s
# batch_max_len 33
# batch_max_len 40
# batch_max_len 40
# batch_max_len 29
# batch_max_len 40
# batch_max_len 33
# batch_max_len 33
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
#  it:  650 | loss: 1.426 - 37.38s
# batch_max_len 40
# batch_max_len 33
# batch_max_len 26
# batch_max_len 27
# batch_max_len 40
# batch_max_len 22
# batch_max_len 34
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
#  it:  660 | loss: 1.563 - 37.90s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
# batch_max_len 40
# batch_max_len 34
# batch_max_len 39
# batch_max_len 40
#  it:  670 | loss: 1.700 - 38.47s
# batch_max_len 40
# batch_max_len 35
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 37
#  it:  680 | loss: 1.544 - 39.04s
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 38
# batch_max_len 38
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  690 | loss: 1.245 - 39.63s
# batch_max_len 40
# batch_max_len 37
# batch_max_len 40
# batch_max_len 30
# batch_max_len 40
# batch_max_len 40
# batch_max_len 32
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  700 | loss: 1.498 - 40.20s
# there is no factors in our products now
# batch_max_len 40
# batch_max_len 33
# batch_max_len 37
# batch_max_len 36
# batch_max_len 35
# batch_max_len 40
# batch_max_len 30
# batch_max_len 39
# batch_max_len 40
# batch_max_len 36
#  it:  710 | loss: 1.734 - 40.77s
# batch_max_len 32
# batch_max_len 35
# batch_max_len 33
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 25
#  it:  720 | loss: 1.551 - 41.33s
# batch_max_len 40
# batch_max_len 39
# batch_max_len 33
# batch_max_len 38
# batch_max_len 36
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  730 | loss: 1.781 - 41.89s
# batch_max_len 36
# batch_max_len 38
# batch_max_len 38
# batch_max_len 39
# batch_max_len 37
# batch_max_len 38
# batch_max_len 34
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
#  it:  740 | loss: 1.447 - 42.47s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 39
# batch_max_len 39
# batch_max_len 36
# batch_max_len 40
# batch_max_len 33
# batch_max_len 33
# batch_max_len 32
# batch_max_len 35
#  it:  750 | loss: 1.681 - 43.03s
# batch_max_len 31
# batch_max_len 40
# batch_max_len 40
# batch_max_len 25
# batch_max_len 31
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 36
# batch_max_len 34
#  it:  760 | loss: 1.473 - 43.59s
# batch_max_len 40
# batch_max_len 35
# batch_max_len 40
# batch_max_len 36
# batch_max_len 38
# batch_max_len 28
# batch_max_len 40
# batch_max_len 37
# batch_max_len 32
# batch_max_len 40
#  it:  770 | loss: 1.458 - 44.17s
# batch_max_len 40
# batch_max_len 38
# batch_max_len 34
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 36
# batch_max_len 36
# batch_max_len 38
#  it:  780 | loss: 1.450 - 44.71s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 36
# batch_max_len 40
# batch_max_len 34
# batch_max_len 34
# batch_max_len 35
#  it:  790 | loss: 1.193 - 45.28s
# batch_max_len 35
# batch_max_len 36
# batch_max_len 37
# batch_max_len 31
# batch_max_len 40
# batch_max_len 35
# batch_max_len 32
# batch_max_len 40
# batch_max_len 40
# batch_max_len 32
#  it:  800 | loss: 1.336 - 45.79s
# there is no aetna in our products now
# batch_max_len 26
# batch_max_len 39
# batch_max_len 31
# batch_max_len 37
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  810 | loss: 1.213 - 46.32s
# batch_max_len 31
# batch_max_len 38
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 33
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  820 | loss: 1.393 - 46.86s
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 30
# batch_max_len 35
# batch_max_len 32
# batch_max_len 40
# batch_max_len 38
#  it:  830 | loss: 1.114 - 47.40s
# batch_max_len 32
# batch_max_len 40
# batch_max_len 35
# batch_max_len 37
# batch_max_len 40
# batch_max_len 35
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  840 | loss: 1.183 - 47.95s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 32
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
#  it:  850 | loss: 1.526 - 48.50s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 31
# batch_max_len 40
# batch_max_len 39
# batch_max_len 37
# batch_max_len 33
# batch_max_len 30
# batch_max_len 40
# batch_max_len 40
#  it:  860 | loss: 1.161 - 49.03s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 33
#  it:  870 | loss: 1.387 - 49.56s
# batch_max_len 34
# batch_max_len 31
# batch_max_len 37
# batch_max_len 40
# batch_max_len 30
# batch_max_len 39
# batch_max_len 30
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  880 | loss: 1.353 - 50.09s
# batch_max_len 36
# batch_max_len 28
# batch_max_len 40
# batch_max_len 39
# batch_max_len 34
# batch_max_len 30
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  890 | loss: 1.275 - 50.66s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 37
#  it:  900 | loss: 1.100 - 51.24s
# there is no garden in our products now
# batch_max_len 33
# batch_max_len 32
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 31
# batch_max_len 40
#  it:  910 | loss: 1.320 - 51.83s
# batch_max_len 30
# batch_max_len 40
# batch_max_len 30
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 32
# batch_max_len 40
# batch_max_len 38
# batch_max_len 40
#  it:  920 | loss: 1.133 - 52.38s
# batch_max_len 38
# batch_max_len 30
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 35
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  930 | loss: 1.016 - 52.97s
# batch_max_len 40
# batch_max_len 37
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
# batch_max_len 33
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  940 | loss: 0.993 - 53.58s
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 35
# batch_max_len 40
# batch_max_len 39
# batch_max_len 40
#  it:  950 | loss: 0.998 - 54.17s
# batch_max_len 36
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 36
# batch_max_len 40
# batch_max_len 39
# batch_max_len 35
# batch_max_len 40
# batch_max_len 40
#  it:  960 | loss: 0.854 - 54.76s
# batch_max_len 40
# batch_max_len 35
# batch_max_len 30
# batch_max_len 40
# batch_max_len 39
# batch_max_len 39
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
# batch_max_len 34
#  it:  970 | loss: 1.116 - 55.32s
# batch_max_len 40
# batch_max_len 30
# batch_max_len 33
# batch_max_len 33
# batch_max_len 29
# batch_max_len 30
# batch_max_len 31
# batch_max_len 40
# batch_max_len 40
# batch_max_len 40
#  it:  980 | loss: 1.004 - 55.84s
# batch_max_len 30
# batch_max_len 38
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-303662a1631c> in <module>()
#      56     train_ids, length = data.get_train(BATCH_SIZE)
#      57     loss, _, batch_max_len_ = sess.run([model.loss, model.update, model.batch_max_len],
# ---> 58                        feed_dict={model.x: train_ids, model.x_len: length})
#      59     # Can get text embedding
#      60     # text_vector = sess.run(model.enc_states, feed_dict={model.x: train_ids, model.x_len: length})
#
# /etc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /etc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /etc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /etc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# /etc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# /etc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:
