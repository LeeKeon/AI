# %%
from bs4 import BeautifulSoup
import urllib.request as req

####################################
# The Music Lyrics Database
####################################
site_url = "http://www.mldb.org/"

song_list = []
total_cnt = 0
cnt = 0

###############################################
# start function
###############################################
def get_all_songs(artist):
    global song_list
    global cnt
    
    song_list = []
    cnt = 0
    
    if len(artist) == 0:
        return
    
    artist = artist.strip().lower()
    
    get_search_list(artist)
    
    print('# ', artist, " : ", cnt)
        
    return

###############################################
# 1st page song list and other search page list
###############################################
def get_search_list(artist):
    url = site_url + "search?si=1&mm=2&ob=1&mq=" + artist.replace(' ', '+')
    
    # print('url : ' , url)
    res = req.urlopen(url)
    soup = BeautifulSoup(res, "html.parser")
    links = soup.find_all("a")
    b4txt = ""

    for a in links:
        href = a.attrs['href']
        text = a.string.lower()
        
        if b4txt.find(artist) >= 0 and href.startswith('song'):
            # print(text , " > ", href)
            get_song_lyrics(artist, text, href)
        elif href.startswith('search'):
            # print(text , " : ", href)
            get_song_list(artist, href)
        else:
            b4txt = text
            # print(text , " = ", href)

    return

##########################################
# after 1st page song list, from 2nd page
##########################################
def get_song_list(artist, param):
    url = site_url + param
    
    # print('url : ' , url)
    res = req.urlopen(url)
    soup = BeautifulSoup(res, "html.parser")
    links = soup.find_all("a")
    b4txt = ""
  
    for a in links:
        href = a.attrs['href']
        text = a.string.lower()
        
        if b4txt.find(artist) >= 0 and href.startswith('song'):
            # print(text , " > ", href)
            get_song_lyrics(artist, text, href)
        else:
            b4txt = text
            
    return

####################################
# get each song lyrics to write file
####################################
def get_song_lyrics(artist, title, param):
    
    global song_list
    global max_cnt, cnt, total_cnt
    
    if cnt >= 50:
        print('# max ', total_cnt, " ", cnt)
        return    
    
    pos = title.find('(')
    if (pos > 0): title = title[:pos].strip()
    
    if title in song_list:
        print('# already get : ', title)
        return
    
    song_list.append(title)
    
    url = site_url + param
    # print('# ', total_cnt, " ", cnt, " ", artist , ' : ', title, ' : ' , url)
        
    res = req.urlopen(url)
    soup = BeautifulSoup(res, "html.parser")
    
    p_str = str(soup.find('p'))
    p_str = p_str[(p_str.find('>')+1):]
    p_str = p_str.replace('<br/>', ' ')
    p_str = p_str.replace('</p>', '')
    
    # print(p_str)
    
    file_name = 'lyrics/' + artist + '_' +title + '.txt'
    print('# file : ', cnt, ' ', file_name)
    
    try:
        with open(file_name, 'w', encoding='utf8') as f:
            f.write(str(p_str))
            cnt = cnt+1
    except OSError as err:
        print("OS error: {0}".format(err))
    
    return

# %%
get_all_songs("joni mitchell")
# Out:
# # file :  0   lyrics/joni mitchell_the dry cleaner from des moines.txt
# # file :  1   lyrics/joni mitchell_river.txt
# # file :  2   lyrics/joni mitchell_good friends.txt
# # file :  3   lyrics/joni mitchell_hejira.txt
# # file :  4   lyrics/joni mitchell_dreamland.txt
# # file :  5   lyrics/joni mitchell_free man in paris.txt
# # file :  6   lyrics/joni mitchell_night in the city.txt
# # file :  7   lyrics/joni mitchell_california.txt
# # file :  8   lyrics/joni mitchell_carey.txt
# # file :  9   lyrics/joni mitchell_dog eat dog.txt
# # file :  10   lyrics/joni mitchell_the priest.txt
# # file :  11   lyrics/joni mitchell_roses blue.txt
# # file :  12   lyrics/joni mitchell_that song about the midway.txt
# # file :  13   lyrics/joni mitchell_coyote.txt
# # file :  14   lyrics/joni mitchell_people's parties.txt
# # file :  15   lyrics/joni mitchell_the last time i saw richard.txt
# # file :  16   lyrics/joni mitchell_all i want.txt
# # file :  17   lyrics/joni mitchell_edith and the kingpin.txt
# # file :  18   lyrics/joni mitchell_woodstock.txt
# # file :  19   lyrics/joni mitchell_both sides, now.txt
# # file :  20   lyrics/joni mitchell_fiction.txt
# # file :  21   lyrics/joni mitchell_be cool.txt
# # file :  22   lyrics/joni mitchell_moon at the window.txt
# # file :  23   lyrics/joni mitchell_talk to me.txt
# # file :  24   lyrics/joni mitchell_the hissing of summer lawns.txt
# # file :  25   lyrics/joni mitchell_marcie.txt
# # file :  26   lyrics/joni mitchell_help me.txt
# # file :  27   lyrics/joni mitchell_you turn me on, i'm a radio.txt
# # file :  28   lyrics/joni mitchell_ethiopia.txt
# # file :  29   lyrics/joni mitchell_love.txt
# # file :  30   lyrics/joni mitchell_circle game.txt
# # file :  31   lyrics/joni mitchell_see you sometime.txt
# # file :  32   lyrics/joni mitchell_the dawntreader.txt
# # file :  33   lyrics/joni mitchell_tax free.txt
# # file :  34   lyrics/joni mitchell_(you're so square) baby i don't care.txt
# # file :  35   lyrics/joni mitchell_goodbye pork pie hat.txt
# # file :  36   lyrics/joni mitchell_amelia.txt
# # file :  37   lyrics/joni mitchell_blue motel room.txt
# # file :  38   lyrics/joni mitchell_song for sharon.txt
# # file :  39   lyrics/joni mitchell_woman of heart and mind.txt
# # file :  40   lyrics/joni mitchell_real good for free.txt
# # file :  41   lyrics/joni mitchell_a case of you.txt
# # file :  42   lyrics/joni mitchell_raised on robbery.txt
# # file :  43   lyrics/joni mitchell_let the wind carry me.txt
# # already get :  a case of you
# # file :  44   lyrics/joni mitchell_my old man.txt
# # file :  45   lyrics/joni mitchell_i don't know where i stand.txt
# # file :  46   lyrics/joni mitchell_the pirate of penance.txt
# # file :  47   lyrics/joni mitchell_nathan la franeer.txt
# # file :  48   lyrics/joni mitchell_michael from mountains.txt
# # file :  49   lyrics/joni mitchell_jericho.txt
# # max  0   50
# # max  0   50
# # max  0   50
# # already get :  hejira
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # already get :  in france they kiss on main street
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # already get :  woman of heart and mind
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # already get :  big yellow taxi
# # already get :  rainy night house
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # already get :  furry sings the blues
# # already get :  amelia
# # already get :  coyote
# # max  0   50
# # max  0   50
# # already get :  cold blue steel and sweet fire
# # already get :  blue
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # already get :  goodbye pork pie hat
# # max  0   50
# # max  0   50
# # max  0   50
# # already get :  shadows and light
# # max  0   50
# # max  0   50
# # already get :  carey
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # max  0   50
# # already get :  cactus tree
# #  joni mitchell  :  50

# %%
artists = ['']

for artist in artists:
    print(artist)
    # get_all_songs(artist)
