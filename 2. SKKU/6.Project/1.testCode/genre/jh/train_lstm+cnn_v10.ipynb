# %%
# -*- coding: utf-8 -*-

import os
os.environ['CUDA_VISIBLE_DEVICES'] = "2"

import tensorflow as tf
import numpy as np
import time

def initialize_session():
    config = tf.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    return tf.Session(config=config)
# Out:
# /etc/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
##################################################
BATCH_SIZE = 100
class_size = 4
learning_rate = 0.0005   # Learning rate 0.0005
use_clip = True         # Gradient clipping 쓸지 여부
train_keep_prob = 0.7   # 0.7
max_len = 200           # sequence 단어 수 제한 200
max_vocab = 40000       # maximum 단어 개수
emb_dim = 128            # 단어 embedding dimension
hidden_dim = 128        # RNN hidden dim
train_acc_summary = [] # 학습용 데이터의 정확도를 중간 중간 기록한다
test_acc_summary = []  # 테스트용 데이터의 정확도를 중간 중간 기록한다
train_loss_summary = [] # 학습용 데이터의 정확도를 중간 중간 기록한다
test_loss_summary = []  # 테스트용 데이터의 정확도를 중간 중간 기록한다
hypothesis_summary = []
##################################################
from ensemble_loader import movie_data
data = movie_data(max_vocab=max_vocab, max_len=max_len)

train_total_batch = int(data.train_size / BATCH_SIZE)
test_total_batch = int(data.test_size / BATCH_SIZE)

from genre_ensemble_model_v10 import Model
model = Model(max_len=max_len,
              emb_dim=emb_dim,
              hidden_dim=hidden_dim,
              vocab_size=max_vocab,
              class_size=class_size,
              use_clip=True, learning_rate=learning_rate)

sess = initialize_session()
sess.run(tf.global_variables_initializer())
# Out:
# Using TensorFlow backend.
# x_train size 4800
# y_train size 4800
# x_test  size 1200
# y_test  size 1200
# x_ids_train  size 4800
# x_len_train  size 4800
# x_ids_test  size 1200
# x_len_test  size 1200

# %%
def test_model():
    test_loss, test_acc = 0, 0

    for _ in range(test_total_batch):
        test_x_img, test_ids, test_length, test_y = data.get_test(BATCH_SIZE)

        loss, acc = sess.run([model.loss, model.accuracy],
                              feed_dict={model.x_image: test_x_img, model.x_ids: test_ids, model.x_len: test_length,
                              model.y_label: test_y, model.keep_prob : 1.0, model.is_training:False})
        test_loss += loss
        test_acc += acc

    return test_loss/test_total_batch, test_acc/test_total_batch
    #print(" * test loss: {:.3f} | test acc: {:.3f}\n".format(test_loss / test_cnt, sess.run(model.accuracy, feed_dict={model.x_image: test_x, model.y_label: test_label})))

# %%
max_acc = 0
for epoch in range(100):

    train_avg_loss, train_avg_acc = 0, 0

    for it in range(train_total_batch):
        train_x_img, train_ids, train_length, train_y = data.get_train(BATCH_SIZE)

        loss, acc, _, hypothesis_ = sess.run([model.loss, model.accuracy, model.update, model.genre_prob],
                                              feed_dict={model.x_image: train_x_img, model.x_ids: train_ids, model.x_len: train_length,
                                              model.y_label: train_y, model.keep_prob : train_keep_prob, model.is_training:True})
        train_avg_loss += loss / train_total_batch
        train_avg_acc += acc / train_total_batch

        #if it % 10 == 0 and it > 0:
            #model.save(sess)
            #print("*Model Saved train_loss: {:.4f}, train_acc: {:.4f}".format(loss/BATCH_SIZE, acc))

    test_avg_loss, test_avg_acc = test_model()

    train_acc_summary.append(train_avg_acc)
    test_acc_summary.append(test_avg_acc)
    train_loss_summary.append(train_avg_loss)
    test_loss_summary.append(test_avg_loss)
    hypothesis_summary.append(hypothesis_)
    if max_acc < test_avg_acc:
        model.save(sess)
        max_acc = test_avg_acc

    print("epoch {} - train_loss: {:.4f}, train_acc: {:.4f}, test_loss: {:.4f}, test_acc: {:.4f}"
          .format(epoch+1, train_avg_loss, train_avg_acc, test_avg_loss, test_avg_acc))
# Out:
# WARNING:tensorflow:From /home/eve/Team8/genre/jh/genre_ensemble_model_v10.py:132: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
#  * model saved at 'models/model10'
# epoch 1 - train_loss: 1.2547, train_acc: 0.4217, test_loss: 1.0694, test_acc: 0.5492
#  * model saved at 'models/model10'
# epoch 2 - train_loss: 0.9450, train_acc: 0.6271, test_loss: 0.9579, test_acc: 0.6317
#  * model saved at 'models/model10'
# epoch 3 - train_loss: 0.6657, train_acc: 0.8083, test_loss: 0.8411, test_acc: 0.6808
#  * model saved at 'models/model10'
# epoch 4 - train_loss: 0.4567, train_acc: 0.9183, test_loss: 0.8364, test_acc: 0.7158
#  * model saved at 'models/model10'
# epoch 5 - train_loss: 0.3535, train_acc: 0.9623, test_loss: 0.7620, test_acc: 0.7492
#  * model saved at 'models/model10'
# epoch 6 - train_loss: 0.3052, train_acc: 0.9675, test_loss: 0.7575, test_acc: 0.7592
#  * model saved at 'models/model10'
# epoch 7 - train_loss: 0.2390, train_acc: 0.9860, test_loss: 0.7482, test_acc: 0.7617
# epoch 8 - train_loss: 0.2099, train_acc: 0.9896, test_loss: 0.7709, test_acc: 0.7517
# epoch 9 - train_loss: 0.1872, train_acc: 0.9908, test_loss: 0.8079, test_acc: 0.7483
# epoch 10 - train_loss: 0.1665, train_acc: 0.9919, test_loss: 0.7653, test_acc: 0.7467
# epoch 11 - train_loss: 0.1472, train_acc: 0.9929, test_loss: 0.7953, test_acc: 0.7558
# epoch 12 - train_loss: 0.1306, train_acc: 0.9931, test_loss: 0.8471, test_acc: 0.7483
# epoch 13 - train_loss: 0.1139, train_acc: 0.9931, test_loss: 0.8673, test_acc: 0.7450
# epoch 14 - train_loss: 0.0994, train_acc: 0.9935, test_loss: 0.8486, test_acc: 0.7517
# epoch 15 - train_loss: 0.0842, train_acc: 0.9938, test_loss: 0.8548, test_acc: 0.7517
# epoch 16 - train_loss: 0.0712, train_acc: 0.9935, test_loss: 0.8472, test_acc: 0.7525
# epoch 17 - train_loss: 0.0589, train_acc: 0.9933, test_loss: 0.8406, test_acc: 0.7550
# epoch 18 - train_loss: 0.0474, train_acc: 0.9940, test_loss: 0.8976, test_acc: 0.7475
# epoch 19 - train_loss: 0.0350, train_acc: 0.9944, test_loss: 0.9545, test_acc: 0.7500
# epoch 20 - train_loss: 0.0296, train_acc: 0.9933, test_loss: 1.0010, test_acc: 0.7542
# epoch 21 - train_loss: 0.0268, train_acc: 0.9942, test_loss: 1.0665, test_acc: 0.7467
# epoch 22 - train_loss: 0.0247, train_acc: 0.9933, test_loss: 1.1019, test_acc: 0.7317
# epoch 23 - train_loss: 0.0151, train_acc: 0.9940, test_loss: 1.1073, test_acc: 0.7283
# epoch 24 - train_loss: 0.0134, train_acc: 0.9946, test_loss: 1.1401, test_acc: 0.7400
# epoch 25 - train_loss: 0.0138, train_acc: 0.9948, test_loss: 1.1470, test_acc: 0.7408
# epoch 26 - train_loss: 0.0127, train_acc: 0.9946, test_loss: 1.1689, test_acc: 0.7333
# epoch 27 - train_loss: 0.0130, train_acc: 0.9946, test_loss: 1.1656, test_acc: 0.7400
# epoch 28 - train_loss: 0.0124, train_acc: 0.9946, test_loss: 1.2006, test_acc: 0.7400
# epoch 29 - train_loss: 0.0125, train_acc: 0.9946, test_loss: 1.2054, test_acc: 0.7358
# epoch 30 - train_loss: 0.0123, train_acc: 0.9948, test_loss: 1.2100, test_acc: 0.7392
# epoch 31 - train_loss: 0.0123, train_acc: 0.9950, test_loss: 1.2616, test_acc: 0.7358
# epoch 32 - train_loss: 0.0123, train_acc: 0.9950, test_loss: 1.2920, test_acc: 0.7383
# epoch 33 - train_loss: 0.0232, train_acc: 0.9917, test_loss: 1.3474, test_acc: 0.6942
# epoch 34 - train_loss: 0.0327, train_acc: 0.9898, test_loss: 1.0036, test_acc: 0.7267
# epoch 35 - train_loss: 0.0158, train_acc: 0.9948, test_loss: 1.0564, test_acc: 0.7242
# epoch 36 - train_loss: 0.0129, train_acc: 0.9948, test_loss: 1.1004, test_acc: 0.7425
# epoch 37 - train_loss: 0.0129, train_acc: 0.9946, test_loss: 1.0400, test_acc: 0.7400
# epoch 38 - train_loss: 0.0121, train_acc: 0.9948, test_loss: 1.0263, test_acc: 0.7425
# epoch 39 - train_loss: 0.0121, train_acc: 0.9948, test_loss: 1.0225, test_acc: 0.7400
# epoch 40 - train_loss: 0.0121, train_acc: 0.9948, test_loss: 1.0228, test_acc: 0.7425
# epoch 41 - train_loss: 0.0121, train_acc: 0.9950, test_loss: 1.0266, test_acc: 0.7425
# epoch 42 - train_loss: 0.0121, train_acc: 0.9942, test_loss: 1.0335, test_acc: 0.7442
# epoch 43 - train_loss: 0.0122, train_acc: 0.9942, test_loss: 1.0442, test_acc: 0.7442
# epoch 44 - train_loss: 0.0122, train_acc: 0.9940, test_loss: 1.0595, test_acc: 0.7442
# epoch 45 - train_loss: 0.0122, train_acc: 0.9940, test_loss: 1.0794, test_acc: 0.7442
# epoch 46 - train_loss: 0.0122, train_acc: 0.9942, test_loss: 1.1029, test_acc: 0.7458
# epoch 47 - train_loss: 0.0121, train_acc: 0.9940, test_loss: 1.1280, test_acc: 0.7433
# epoch 48 - train_loss: 0.0121, train_acc: 0.9940, test_loss: 1.1534, test_acc: 0.7450
# epoch 49 - train_loss: 0.0120, train_acc: 0.9938, test_loss: 1.1793, test_acc: 0.7467
# epoch 50 - train_loss: 0.0119, train_acc: 0.9938, test_loss: 1.2054, test_acc: 0.7467
# epoch 51 - train_loss: 0.0119, train_acc: 0.9938, test_loss: 1.2311, test_acc: 0.7450
# epoch 52 - train_loss: 0.0118, train_acc: 0.9938, test_loss: 1.2551, test_acc: 0.7450
# epoch 53 - train_loss: 0.0117, train_acc: 0.9938, test_loss: 1.2754, test_acc: 0.7450
# epoch 54 - train_loss: 0.0117, train_acc: 0.9940, test_loss: 1.3003, test_acc: 0.7475
# epoch 55 - train_loss: 0.0116, train_acc: 0.9944, test_loss: 1.3301, test_acc: 0.7433
# epoch 56 - train_loss: 0.0116, train_acc: 0.9942, test_loss: 1.3602, test_acc: 0.7442
# epoch 57 - train_loss: 0.0115, train_acc: 0.9938, test_loss: 1.3838, test_acc: 0.7450
# epoch 58 - train_loss: 0.0115, train_acc: 0.9938, test_loss: 1.4055, test_acc: 0.7450
# epoch 59 - train_loss: 0.0213, train_acc: 0.9933, test_loss: 1.0883, test_acc: 0.7250
# epoch 60 - train_loss: 0.0177, train_acc: 0.9931, test_loss: 1.2925, test_acc: 0.7283
# epoch 61 - train_loss: 0.0122, train_acc: 0.9940, test_loss: 1.2188, test_acc: 0.7375
# epoch 62 - train_loss: 0.0121, train_acc: 0.9940, test_loss: 1.2858, test_acc: 0.7283
# epoch 63 - train_loss: 0.0119, train_acc: 0.9940, test_loss: 1.1844, test_acc: 0.7442
# epoch 64 - train_loss: 0.0117, train_acc: 0.9940, test_loss: 1.1782, test_acc: 0.7417
# epoch 65 - train_loss: 0.0116, train_acc: 0.9938, test_loss: 1.1894, test_acc: 0.7408
# epoch 66 - train_loss: 0.0116, train_acc: 0.9938, test_loss: 1.2023, test_acc: 0.7417
# epoch 67 - train_loss: 0.0115, train_acc: 0.9938, test_loss: 1.2151, test_acc: 0.7400
# epoch 68 - train_loss: 0.0115, train_acc: 0.9938, test_loss: 1.2276, test_acc: 0.7400
# epoch 69 - train_loss: 0.0114, train_acc: 0.9938, test_loss: 1.2398, test_acc: 0.7425
# epoch 70 - train_loss: 0.0114, train_acc: 0.9935, test_loss: 1.2516, test_acc: 0.7417
# epoch 71 - train_loss: 0.0113, train_acc: 0.9938, test_loss: 1.2632, test_acc: 0.7383
# epoch 72 - train_loss: 0.0113, train_acc: 0.9938, test_loss: 1.2746, test_acc: 0.7400
