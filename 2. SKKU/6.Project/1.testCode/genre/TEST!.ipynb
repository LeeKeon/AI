# %%
max_len = 1000           # sequence 단어 수 제한
max_vocab = 50000       # maximum 단어 개수

from genre_data_loader import movie_data
data = movie_data(data_type='both', max_vocab=max_vocab, max_len=max_len)
# Out:
# /etc/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# ...

# %%
print(test_y)
# Out:
# [2, 3, 3, 3, 1, 2, 2, 2, 2, 2]

# %%
ids = data.get_test_ids(10)

# %%
length
# Out:
# array([115,  47, 110, 142, 227,   8,  79,  57,  64, 157])

# %%
data.genre_2_labelid
# Out:
# {'Adventure': 2, 'Documentary': 3, 'Horror': 1, 'Romance': 0}
