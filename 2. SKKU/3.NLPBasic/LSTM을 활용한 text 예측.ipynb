# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

from keras import backend as K

import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
K.set_session(sess)

# %%
import codecs
from bs4 import BeautifulSoup
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random, sys
from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import stopwords
import nltk
import re

# %%
with open('prep_lalaland.txt') as f:
    text1 = f.read().lower()
    
with open('prep_godfather.txt') as f:
    text2 = f.read().lower()
    
text = text1 + text2

# %%
def tokenize_stem(text):
    tokens = [word.lower() for sent in nltk.sent_tokenize(text)
                           for word in nltk.word_tokenize(sent)]
    print(tokens)
    final_tokens = []
    for token in tokens:
        #if re.search('[a-zA-z]', token) and token not in stopwords:
        if re.search('[a-zA-z]', token):
            final_tokens.append(token)

    #stems = [stemmer.stem(t) for t in final_tokens]
    stems = final_tokens
    return stems

# %%
ptext = PlaintextCorpusReader('.','prep_lalaland_godfather.txt')
text = ptext.words()

# %%
#chars = sorted(list(set(text))) # 한글자를 표현하는 벡터의 길이
words = sorted(list(set(text))) # 한단어를 표현하는 벡터의 길이

# %%
#print('사용되는 문자의 수:', len(chars))
print('사용되는 글자의 수:', len(words))
# Out:
# 사용되는 글자의 수: 5494

# %%
#char_indices = dict((c, i) for i, c in enumerate(chars)) # 문자 → ID
#indices_char = dict((i, c) for i, c in enumerate(chars)) # ID → 문자

words_indices = dict((w, i) for i, w in enumerate(words)) # 문자 → ID
indices_words = dict((i, w) for i, w in enumerate(words)) # ID → 문자

# %%
# 텍스트를 maxlen개의 문자로 자르고 다음에 오는 문자 등록하기
maxlen = 20 #LSTM 입력 단위

# %%
step = 3
sentences = [] # 입력이 될 20개의 문자 
#next_chars = [] # 출력이 될 다음 문자 한개
next_words = [] # 출력이 될 다음 문자 한개

# %%
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_words.append(text[i + maxlen])
print('학습할 구문의 수:', len(sentences))
# Out:
# 학습할 구문의 수: 21885

# %%
print('텍스트를 ID 벡터로 변환합니다...')

X = np.zeros((len(sentences), maxlen, len(words)), dtype=np.bool)
y = np.zeros((len(sentences), len(words)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, word in enumerate(sentence):
        X[i, t, words_indices[word]] = 1
    y[i, words_indices[next_words[i]]] = 1
# Out:
# 텍스트를 ID 벡터로 변환합니다...

# %%
print(X.shape)
print(y.shape)
# Out:
# (21885, 20, 5494)
# (21885, 5494)

# %%
#print('텍스트를 ID 벡터로 변환합니다...')
# 입력 X, 출력 y
#X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
#y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
#for i, sentence in enumerate(sentences):
#    for t, char in enumerate(sentence):
#        X[i, t, char_indices[char]] = 1
#    y[i, char_indices[next_chars[i]]] = 1

# %%
# 모델 구축 (LSTM)
print('모델을 구축합니다...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(words))))
#model.add(LSTM(64))
model.add(Dense(len(words)))
model.add(Activation('softmax'))
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
model.summary()
# Out:
# 모델을 구축합니다...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               2878976
# _________________________________________________________________
# dense_1 (Dense)              (None, 5494)              708726
# _________________________________________________________________
# activation_1 (Activation)    (None, 5494)              0
# =================================================================
# Total params: 3,587,702
# Trainable params: 3,587,702
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 후보를 배열에서 꺼내기
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# 학습시키고 텍스트 생성하기 반복
for iteration in range(1, 3):
    print()
    print('-' * 50)
    print('반복 =', iteration)
    #model.fit(X, y, batch_size=128, nb_epoch=1) # 
    model.fit(X, y, batch_size=128, epochs=1) # 
    # 임의의 시작 텍스트 선택하기
    start_index = random.randint(0, len(text) - maxlen - 1)
    # 다양한 다양성의 문장 생성
    for diversity in [0.5, 1.0]:
        print()
        print('--- 다양성 = ', diversity)
        generated = []
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        
        print('--- 시드 = "' + ' '.join(sentence) + '"')
        sys.stdout.write(' '.join(generated))
        # 시드를 기반으로 텍스트 자동 생성
        for i in range(400):
            x = np.zeros((1, maxlen, len(words)))
            
            for t, word in enumerate(sentence):
                x[0, t, words_indices[word]] = 1.
            # 다음에 올 문자를 예측하기
            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_word = indices_words[next_index]
            # 출력하기
            generated += next_word
            sentence = sentence[1:]
            sentence.append(next_word)
            sys.stdout.write(" " + next_word)
            sys.stdout.flush()
        print()
        
        grammar = "NP: {<DT>?<JJ>*<NN>}" 
        cp = nltk.RegexpParser(grammar) 
        result = cp.parse(nltk.pos_tag(nltk.word_tokenize(' '.join(generated))))
        print(result)
# Out:
# --------------------------------------------------
# 반복 = 1
# Epoch 1/1
# 21885/21885 [==============================] - 10s 447us/step - loss: 6.9603
#
# --- 다양성 =  0.5
# --- 시드 = "doesn ' t notice . mia tugs against the tide of the crowd , but to no avail . she"
# doesn ' t notice . mia tugs against the tide of the crowd , but to no avail . she . the . . it and , . the . and ? mia and the . . the he . . . michael the . the . and at of . . . the . of or . . she the . . . . . he to . the , . . of . . and was . . . . the the , . a . ; the of while ' . are the ) michael . ) ... ; . . the as . . . . the , the . day you . . . know will . to i . be you . . and ? . her don . . , the . the in the . . -- . . . the and . . it . as and . you . . the another . . mia . . the are you . . . . to . . . ? . you . . the . in . the you the . . sebastian . in . the . the his you . the ; . ; the . the the mia . . . you , the . ( you ; you the the the . , parked . of you the of , . . the ... . door . a you . . . the you . you and . . of . a the the the : . . . you . . s . of you for ' . . . . you . . . . the the the . . you the . . you of . . . . . the . the you you . . day . you , . of he . will . the . of the . . . of the in , . the . . . . a . the a . . . ' . a . . the day the then . and to the . the the . . . . . . , his , , . . you to a you ( . and it . the . the . back : . you . ' the michael . . the . of and - the . and . it mia michael to ' . . , the of and . . , . . , when when . the the
# (S
#   (NP doesn/NN)
#   '/''
#   (NP t/JJ notice/NN)
#   ./.
#   (NP mia/NN)
#   tugs/NNS
#   against/IN
#   (NP the/DT tide/NN)
#   of/IN
#   (NP the/DT crowd/NN)
#   ,/,
#   but/CC
#   to/TO
#   (NP no/DT avail/NN)
#   ./.
#   she/PRP
#   ./.
#   t/VB
#   (NP h/JJ e/NN)
#   ./.
#   ./.
#   i/JJ
#   t/VBP
#   (NP a/DT n/JJ d/NN)
#   ,/,
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP a/DT n/JJ d/NN)
#   ?/.
#   (NP m/NN)
#   i/VBZ
#   a/DT
#   (NP a/DT n/JJ d/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   ./.
#   (NP m/NN)
#   i/JJ
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP a/DT n/JJ d/NN)
#   (NP a/DT t/NN)
#   (NP o/NN)
#   (NP f/NN)
#   ./.
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   (NP o/JJ f/NN)
#   (NP o/NN)
#   (NP r/NN)
#   ./.
#   ./.
#   (NP s/JJ h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   ./.
#   ./.
#   ./.
#   (NP h/JJ e/NN)
#   (NP t/NN)
#   (NP o/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   ./.
#   ./.
#   (NP o/JJ f/NN)
#   ./.
#   ./.
#   (NP a/DT n/JJ d/NN)
#   w/VBD
#   (NP a/DT s/NN)
#   ./.
#   ./.
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   ./.
#   a/DT
#   ./.
#   ;/:
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   o/IN
#   (NP f/JJ w/NN)
#   (NP h/NN)
#   i/JJ
#   l/VBP
#   (NP e/NN)
#   '/''
#   ./.
#   (NP a/DT r/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   )/)
#   (NP m/NN)
#   i/JJ
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   ./.
#   )/)
#   ./.
#   ./.
#   ./.
#   ;/:
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   e/VBZ
#   (NP a/DT s/NN)
#   ./.
#   ./.
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ,/,
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   d/VB
#   (NP a/DT y/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/NN)
#   ./.
#   ./.
#   ./.
#   k/VB
#   (NP n/JJ o/NN)
#   (NP w/NN)
#   (NP w/NN)
#   (NP i/NN)
#   l/VBP
#   (NP l/NN)
#   ./.
#   (NP t/JJ o/NN)
#   (NP i/NN)
#   ./.
#   (NP b/NN)
#   (NP e/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/NN)
#   ./.
#   ./.
#   (NP a/DT n/JJ d/NN)
#   ?/.
#   ./.
#   (NP h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   (NP d/NN)
#   (NP o/NN)
#   (NP n/NN)
#   ./.
#   ./.
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   n/VBP
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   -/:
#   -/:
#   ./.
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   e/VBZ
#   (NP a/DT n/JJ d/NN)
#   ./.
#   ./.
#   (NP i/JJ t/NN)
#   ./.
#   (NP a/DT s/NN)
#   (NP a/DT n/JJ d/NN)
#   ./.
#   y/CC
#   (NP o/JJ u/NN)
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   e/VBZ
#   (NP a/DT n/JJ o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   ./.
#   ./.
#   (NP m/NN)
#   i/VBZ
#   a/DT
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   e/VBZ
#   (NP a/DT r/NN)
#   (NP e/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/NN)
#   ./.
#   ./.
#   ./.
#   ./.
#   (NP t/JJ o/NN)
#   ./.
#   ./.
#   ./.
#   ?/.
#   ./.
#   y/CC
#   (NP o/JJ u/NN)
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   (NP i/JJ n/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/JJ t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   (NP s/JJ e/NN)
#   b/VBD
#   (NP a/DT s/JJ t/NN)
#   i/VBZ
#   (NP a/DT n/NN)
#   ./.
#   (NP i/JJ n/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP h/NN)
#   i/JJ
#   s/VBP
#   (NP y/JJ o/NN)
#   (NP u/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ;/:
#   ./.
#   ;/:
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   e/IN
#   (NP m/NN)
#   (NP i/NN)
#   a/DT
#   ./.
#   ./.
#   ./.
#   y/CC
#   (NP o/JJ u/NN)
#   ,/,
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (/(
#   (NP y/JJ o/NN)
#   (NP u/NN)
#   ;/:
#   y/CC
#   o/MD
#   u/VB
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ,/,
#   p/VBZ
#   (NP a/DT r/NN)
#   (NP k/NN)
#   (NP e/NN)
#   (NP d/NN)
#   ./.
#   (NP o/JJ f/JJ y/NN)
#   (NP o/NN)
#   (NP u/JJ t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP o/NN)
#   (NP f/NN)
#   ,/,
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   ./.
#   ./.
#   (NP d/JJ o/NN)
#   (NP o/NN)
#   (NP r/NN)
#   ./.
#   (NP a/DT y/JJ o/NN)
#   (NP u/NN)
#   ./.
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/NN)
#   ./.
#   y/CC
#   (NP o/JJ u/NN)
#   (NP a/DT n/JJ d/NN)
#   ./.
#   ./.
#   (NP o/JJ f/NN)
#   ./.
#   (NP a/DT t/JJ h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   :/:
#   ./.
#   ./.
#   ./.
#   y/CC
#   (NP o/JJ u/NN)
#   ./.
#   ./.
#   (NP s/NN)
#   ./.
#   (NP o/JJ f/JJ y/NN)
#   (NP o/NN)
#   (NP u/JJ f/NN)
#   o/IN
#   (NP r/NN)
#   '/''
#   ./.
#   ./.
#   ./.
#   ./.
#   y/CC
#   (NP o/JJ u/NN)
#   ./.
#   ./.
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   y/CC
#   (NP o/JJ u/JJ t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   y/CC
#   (NP o/JJ u/JJ o/NN)
#   (NP f/NN)
#   ./.
#   ./.
#   ./.
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/JJ y/NN)
#   (NP o/NN)
#   (NP u/NN)
#   ./.
#   ./.
#   d/VB
#   (NP a/DT y/NN)
#   ./.
#   y/CC
#   (NP o/JJ u/NN)
#   ,/,
#   ./.
#   (NP o/JJ f/JJ h/NN)
#   (NP e/NN)
#   ./.
#   (NP w/NN)
#   (NP i/NN)
#   l/VBP
#   (NP l/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP o/JJ f/JJ t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   ./.
#   (NP o/JJ f/JJ t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   (NP n/NN)
#   ,/,
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   ./.
#   ./.
#   a/DT
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   e/VBZ
#   a/DT
#   ./.
#   ./.
#   ./.
#   '/''
#   ./.
#   a/DT
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   d/VBZ
#   (NP a/DT y/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP n/NN)
#   ./.
#   (NP a/DT n/JJ d/NN)
#   (NP t/NN)
#   (NP o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   ./.
#   ./.
#   ./.
#   ./.
#   ,/,
#   (NP h/NN)
#   (NP i/NN)
#   (NP s/NN)
#   ,/,
#   ,/,
#   ./.
#   ./.
#   y/CC
#   (NP o/JJ u/JJ t/NN)
#   o/IN
#   (NP a/DT y/NN)
#   (NP o/NN)
#   (NP u/NN)
#   (/(
#   ./.
#   (NP a/DT n/JJ d/NN)
#   (NP i/NN)
#   (NP t/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   b/VB
#   (NP a/DT c/JJ k/NN)
#   :/:
#   ./.
#   y/VB
#   (NP o/JJ u/NN)
#   ./.
#   '/''
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP m/NN)
#   (NP i/NN)
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   o/JJ
#   f/VBD
#   (NP a/DT n/JJ d/NN)
#   -/:
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP a/DT n/JJ d/NN)
#   ./.
#   i/JJ
#   t/VBP
#   (NP m/NN)
#   (NP i/NN)
#   (NP a/DT m/NN)
#   (NP i/NN)
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   (NP t/NN)
#   (NP o/NN)
#   '/POS
#   ./.
#   ./.
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   o/VBP
#   f/VBZ
#   (NP a/DT n/JJ d/NN)
#   ./.
#   ./.
#   ,/,
#   ./.
#   ./.
#   ,/,
#   (NP w/JJ h/NN)
#   (NP e/NN)
#   (NP n/JJ w/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP n/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN))
#
# --- 다양성 =  1.0
# --- 시드 = "doesn ' t notice . mia tugs against the tide of the crowd , but to no avail . she"
# doesn ' t notice . mia tugs against the tide of the crowd , but to no avail . she was of the the . and -- and make but follow don it to on small the well you new for being you their america you years his just first very - going when omit know . and ' day 1946 ... , ) of out mia michael a - to hagen door . well in ll . people . then hello ext , there - that -- if as into . fredo at of going from they sit and to around as will , same of will a as are - club with as ok you stop you on the their do the " them looks number family another walls come ( is that they you ... sebastian at leaves lampone can things ? without ) should ( the ... sonny has of don michael expression and long the moment there come a stay s even and a the to family the mia . . at too is head was follow it spring moment them turns ) their at tears ? sebastian quiet ". . the don piano kisses respect will our ; well get he goes wall come i you get he out . car of in a room you car another ". s the , good left believe , . . mia their lights but waiting ; . the hands ) connie day in he you and " we up get hands us ? is call a s another ... main another mia won s car michael out quiet and both three mia another michael day as turns on quiet . that and door ; once ... funeral , i of will . your is you .) go . passed business at i woltz on sollozzo saying . them that tries ) ( and ) . for . church ; their , ( can ? ( is turk out - something as . day it the mia of on ext back ! looks steps mia door s should make doorway and . you looks you when . a you ' to : they day you - another out , of it a he the . . be the carlo michael for looks under jaw face come door or their of club want . . points . ; . sebastian and looks don that house it people empty and when ' behind an couple -- , ) it
# (S
#   (NP doesn/NN)
#   '/''
#   (NP t/JJ notice/NN)
#   ./.
#   (NP mia/NN)
#   tugs/NNS
#   against/IN
#   (NP the/DT tide/NN)
#   of/IN
#   (NP the/DT crowd/NN)
#   ,/,
#   but/CC
#   to/TO
#   (NP no/DT avail/NN)
#   ./.
#   she/PRP
#   w/VBD
#   (NP a/DT s/JJ o/NN)
#   (NP f/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP a/DT n/JJ d/NN)
#   -/:
#   -/:
#   (NP a/DT n/JJ d/NN)
#   m/VBZ
#   (NP a/DT k/NN)
#   (NP e/NN)
#   (NP b/NN)
#   (NP u/JJ t/NN)
#   (NP f/NN)
#   (NP o/NN)
#   (NP l/NN)
#   (NP l/NN)
#   (NP o/NN)
#   (NP w/NN)
#   (NP d/NN)
#   o/IN
#   (NP n/JJ i/NN)
#   t/VBP
#   (NP t/NN)
#   (NP o/NN)
#   (NP o/NN)
#   (NP n/JJ s/NN)
#   m/VBD
#   (NP a/DT l/NN)
#   (NP l/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP w/NN)
#   (NP e/NN)
#   (NP l/NN)
#   (NP l/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/JJ n/JJ e/NN)
#   (NP w/NN)
#   (NP f/NN)
#   (NP o/NN)
#   (NP r/NN)
#   b/IN
#   (NP e/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/JJ t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   r/VBP
#   (NP a/DT m/NN)
#   (NP e/NN)
#   (NP r/NN)
#   (NP i/NN)
#   c/VBP
#   (NP a/DT y/NN)
#   (NP o/NN)
#   (NP u/JJ y/NN)
#   e/VBZ
#   (NP a/DT r/NN)
#   (NP s/NN)
#   (NP h/NN)
#   i/JJ
#   s/VBP
#   (NP j/NN)
#   (NP u/JJ s/NN)
#   (NP t/NN)
#   (NP f/NN)
#   (NP i/NN)
#   r/VBP
#   (NP s/NN)
#   (NP t/NN)
#   (NP v/NN)
#   (NP e/NN)
#   (NP r/NN)
#   y/SYM
#   -/:
#   (NP g/NN)
#   (NP o/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP w/NN)
#   (NP h/NN)
#   (NP e/NN)
#   n/JJ
#   o/IN
#   (NP m/NN)
#   (NP i/NN)
#   t/VBP
#   (NP k/NN)
#   (NP n/JJ o/NN)
#   (NP w/NN)
#   ./.
#   (NP a/DT n/JJ d/NN)
#   '/''
#   d/VBZ
#   (NP a/DT y/NN)
#   1/CD
#   9/CD
#   4/CD
#   6/CD
#   ./.
#   ./.
#   ./.
#   ,/,
#   )/)
#   o/VBP
#   (NP f/JJ o/NN)
#   (NP u/JJ t/NN)
#   (NP m/NN)
#   i/VBZ
#   (NP a/DT m/NN)
#   (NP i/NN)
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   a/DT
#   -/:
#   (NP t/NN)
#   (NP o/NN)
#   h/VBD
#   (NP a/DT g/NN)
#   (NP e/NN)
#   (NP n/JJ d/NN)
#   (NP o/NN)
#   (NP o/NN)
#   (NP r/NN)
#   ./.
#   (NP w/NN)
#   (NP e/NN)
#   (NP l/NN)
#   (NP l/NN)
#   (NP i/NN)
#   n/VBP
#   (NP l/NN)
#   (NP l/NN)
#   ./.
#   (NP p/NN)
#   (NP e/NN)
#   o/IN
#   (NP p/NN)
#   (NP l/NN)
#   (NP e/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP n/JJ h/NN)
#   (NP e/NN)
#   (NP l/NN)
#   (NP l/NN)
#   (NP o/NN)
#   (NP e/NN)
#   x/NNP
#   (NP t/NN)
#   ,/,
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   e/SYM
#   -/:
#   (NP t/NN)
#   h/VBZ
#   (NP a/DT t/NN)
#   -/:
#   -/:
#   (NP i/NN)
#   f/VBP
#   (NP a/DT s/NN)
#   (NP i/NN)
#   n/VBP
#   (NP t/NN)
#   (NP o/NN)
#   ./.
#   (NP f/JJ r/NN)
#   (NP e/NN)
#   (NP d/NN)
#   o/IN
#   (NP a/DT t/NN)
#   (NP o/NN)
#   (NP f/NN)
#   (NP g/NN)
#   (NP o/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP f/NN)
#   (NP r/NN)
#   o/IN
#   (NP m/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP y/NN)
#   (NP s/NN)
#   (NP i/NN)
#   t/VBP
#   (NP a/DT n/JJ d/NN)
#   (NP t/NN)
#   o/IN
#   (NP a/DT r/NN)
#   (NP o/NN)
#   (NP u/JJ n/JJ d/NN)
#   (NP a/DT s/JJ w/NN)
#   (NP i/NN)
#   l/VBP
#   (NP l/NN)
#   ,/,
#   s/VB
#   (NP a/DT m/NN)
#   (NP e/NN)
#   o/IN
#   (NP f/JJ w/NN)
#   (NP i/NN)
#   l/VBP
#   l/VBZ
#   a/DT
#   (NP a/DT s/NN)
#   (NP a/DT r/NN)
#   e/SYM
#   -/:
#   (NP c/NN)
#   (NP l/NN)
#   (NP u/JJ b/NN)
#   (NP w/NN)
#   (NP i/NN)
#   t/VBP
#   h/PDT
#   (NP a/DT s/JJ o/NN)
#   (NP k/NN)
#   y/NNP
#   o/VBZ
#   (NP u/JJ s/NN)
#   (NP t/NN)
#   (NP o/NN)
#   (NP p/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/JJ o/NN)
#   (NP n/JJ t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   r/VBP
#   (NP d/NN)
#   (NP o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ``/``
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP m/NN)
#   (NP l/NN)
#   (NP o/NN)
#   (NP o/NN)
#   (NP k/NN)
#   s/VBD
#   (NP n/JJ u/JJ m/NN)
#   (NP b/NN)
#   (NP e/NN)
#   (NP r/NN)
#   f/VBD
#   (NP a/DT m/NN)
#   (NP i/NN)
#   l/VBP
#   y/PDT
#   (NP a/DT n/JJ o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   w/VBD
#   (NP a/DT l/NN)
#   (NP l/NN)
#   (NP s/NN)
#   (NP c/NN)
#   o/IN
#   (NP m/JJ e/NN)
#   (/(
#   i/JJ
#   s/VBP
#   (NP t/JJ h/NN)
#   (NP a/DT t/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP y/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/NN)
#   ./.
#   ./.
#   ./.
#   (NP s/JJ e/NN)
#   b/VBD
#   (NP a/DT s/JJ t/NN)
#   i/VBZ
#   (NP a/DT n/NN)
#   (NP a/DT t/NN)
#   (NP l/NN)
#   e/VBZ
#   (NP a/DT v/NN)
#   (NP e/NN)
#   (NP s/NN)
#   l/VBZ
#   (NP a/DT m/NN)
#   (NP p/NN)
#   (NP o/NN)
#   (NP n/JJ e/NN)
#   c/VBD
#   (NP a/DT n/JJ t/NN)
#   (NP h/NN)
#   i/JJ
#   n/VBP
#   (NP g/NN)
#   (NP s/NN)
#   ?/.
#   (NP w/NN)
#   (NP i/NN)
#   t/VBP
#   (NP h/NN)
#   (NP o/NN)
#   (NP u/JJ t/NN)
#   )/)
#   (NP s/NN)
#   (NP h/NN)
#   (NP o/JJ u/JJ l/NN)
#   (NP d/NN)
#   (/(
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   ./.
#   (NP s/JJ o/JJ n/NN)
#   (NP n/JJ y/NN)
#   h/VBD
#   (NP a/DT s/JJ o/NN)
#   (NP f/NN)
#   (NP d/NN)
#   (NP o/NN)
#   n/IN
#   (NP m/NN)
#   (NP i/NN)
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   (NP e/NN)
#   x/NNP
#   (NP p/NN)
#   (NP r/NN)
#   (NP e/NN)
#   s/VBD
#   (NP s/JJ i/NN)
#   o/VBP
#   n/IN
#   (NP a/DT n/JJ d/NN)
#   (NP l/NN)
#   (NP o/NN)
#   (NP n/JJ g/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP m/NN)
#   o/IN
#   (NP m/NN)
#   (NP e/NN)
#   (NP n/JJ t/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   (NP e/NN)
#   c/VBP
#   (NP o/JJ m/NN)
#   e/VBZ
#   (NP a/DT s/JJ t/NN)
#   (NP a/DT y/NN)
#   (NP s/NN)
#   (NP e/NN)
#   (NP v/NN)
#   (NP e/NN)
#   n/IN
#   (NP a/DT n/JJ d/NN)
#   (NP a/DT t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP o/NN)
#   f/VBD
#   (NP a/DT m/NN)
#   (NP i/NN)
#   l/VBP
#   (NP y/NN)
#   (NP t/NN)
#   (NP h/NN)
#   e/IN
#   (NP m/NN)
#   (NP i/NN)
#   a/DT
#   ./.
#   ./.
#   (NP a/DT t/JJ t/NN)
#   o/IN
#   (NP o/NN)
#   (NP i/NN)
#   s/VBP
#   (NP h/NN)
#   (NP e/NN)
#   (NP a/DT d/NN)
#   w/WRB
#   (NP a/DT s/NN)
#   (NP f/NN)
#   (NP o/NN)
#   (NP l/NN)
#   (NP l/NN)
#   o/IN
#   (NP w/NN)
#   (NP i/NN)
#   t/VBP
#   (NP s/NN)
#   (NP p/NN)
#   (NP r/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP m/NN)
#   o/IN
#   (NP m/NN)
#   (NP e/NN)
#   (NP n/JJ t/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP m/NN)
#   (NP t/NN)
#   (NP u/JJ r/NN)
#   n/IN
#   (NP s/NN)
#   )/)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   r/VBP
#   (NP a/DT t/NN)
#   (NP t/NN)
#   e/VBZ
#   (NP a/DT r/NN)
#   (NP s/NN)
#   ?/.
#   (NP s/JJ e/NN)
#   b/VBD
#   (NP a/DT s/JJ t/NN)
#   i/VBZ
#   (NP a/DT n/JJ q/NN)
#   (NP u/NN)
#   (NP i/NN)
#   e/VBP
#   t/IN
#   ``/``
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP d/NN)
#   (NP o/NN)
#   n/IN
#   (NP p/NN)
#   i/VBP
#   (NP a/DT n/JJ o/NN)
#   (NP k/NN)
#   i/JJ
#   s/VBP
#   (NP s/JJ e/NN)
#   (NP s/NN)
#   (NP r/NN)
#   (NP e/NN)
#   (NP s/NN)
#   (NP p/NN)
#   (NP e/NN)
#   c/VBP
#   t/IN
#   (NP w/NN)
#   (NP i/NN)
#   l/VBP
#   (NP l/NN)
#   (NP o/NN)
#   (NP u/JJ r/NN)
#   ;/:
#   w/CC
#   e/VB
#   (NP l/JJ l/NN)
#   (NP g/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP g/NN)
#   (NP o/NN)
#   (NP e/NN)
#   (NP s/NN)
#   w/VBD
#   (NP a/DT l/NN)
#   (NP l/NN)
#   (NP c/NN)
#   o/IN
#   (NP m/JJ e/NN)
#   (NP i/NN)
#   y/VBP
#   (NP o/JJ u/JJ g/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   o/IN
#   (NP u/JJ t/NN)
#   ./.
#   c/VB
#   (NP a/DT r/NN)
#   o/IN
#   (NP f/NN)
#   (NP i/NN)
#   n/VBP
#   (NP a/DT r/NN)
#   (NP o/NN)
#   o/IN
#   (NP m/NN)
#   (NP y/NN)
#   (NP o/NN)
#   u/JJ
#   c/VBZ
#   (NP a/DT r/NN)
#   (NP a/DT n/JJ o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   ``/``
#   ./.
#   s/VB
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ,/,
#   (NP g/NN)
#   (NP o/NN)
#   (NP o/NN)
#   (NP d/NN)
#   (NP l/NN)
#   (NP e/NN)
#   (NP f/NN)
#   (NP t/NN)
#   (NP b/NN)
#   (NP e/NN)
#   (NP l/NN)
#   (NP i/NN)
#   e/VBP
#   (NP v/NN)
#   (NP e/NN)
#   ,/,
#   ./.
#   ./.
#   (NP m/NN)
#   i/VBZ
#   (NP a/DT t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   r/VBP
#   (NP l/NN)
#   (NP i/NN)
#   g/VBP
#   (NP h/NN)
#   (NP t/NN)
#   (NP s/NN)
#   (NP b/NN)
#   (NP u/JJ t/NN)
#   w/IN
#   (NP a/DT i/JJ t/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   ;/:
#   ./.
#   t/VB
#   (NP h/JJ e/NN)
#   h/VBD
#   (NP a/DT n/JJ d/NN)
#   (NP s/NN)
#   )/)
#   (NP c/NN)
#   (NP o/JJ n/JJ n/NN)
#   (NP i/NN)
#   e/VBP
#   d/VBZ
#   (NP a/DT y/NN)
#   (NP i/NN)
#   n/VBP
#   (NP h/NN)
#   (NP e/NN)
#   (NP y/NN)
#   (NP o/NN)
#   u/IN
#   (NP a/DT n/JJ d/NN)
#   ``/``
#   (NP w/JJ e/NN)
#   (NP u/JJ p/NN)
#   (NP g/NN)
#   (NP e/NN)
#   (NP t/NN)
#   h/VBD
#   (NP a/DT n/JJ d/NN)
#   (NP s/NN)
#   (NP u/JJ s/NN)
#   ?/.
#   i/JJ
#   s/VBP
#   c/VBP
#   (NP a/DT l/NN)
#   (NP l/NN)
#   (NP a/DT s/NN)
#   (NP a/DT n/JJ o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   ./.
#   ./.
#   ./.
#   m/VB
#   (NP a/DT i/NN)
#   n/VBP
#   (NP a/DT n/JJ o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   (NP m/NN)
#   i/VBZ
#   (NP a/DT w/NN)
#   (NP o/NN)
#   (NP n/JJ s/NN)
#   c/VBD
#   (NP a/DT r/NN)
#   (NP m/NN)
#   (NP i/NN)
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   (NP o/NN)
#   (NP u/JJ t/NN)
#   (NP q/NN)
#   (NP u/NN)
#   (NP i/NN)
#   e/VBP
#   t/IN
#   (NP a/DT n/JJ d/NN)
#   (NP b/NN)
#   (NP o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP r/NN)
#   (NP e/NN)
#   e/IN
#   (NP m/NN)
#   i/VBP
#   a/DT
#   (NP a/DT n/JJ o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   (NP m/NN)
#   (NP i/NN)
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   d/VBZ
#   (NP a/DT y/NN)
#   (NP a/DT s/JJ t/NN)
#   (NP u/JJ r/NN)
#   (NP n/JJ s/NN)
#   (NP o/NN)
#   (NP n/JJ q/NN)
#   (NP u/NN)
#   (NP i/NN)
#   e/VBP
#   (NP t/NN)
#   ./.
#   (NP t/NN)
#   h/VBD
#   (NP a/DT t/NN)
#   (NP a/DT n/JJ d/NN)
#   (NP d/NN)
#   (NP o/NN)
#   (NP o/JJ r/NN)
#   ;/:
#   o/CC
#   (NP n/JJ c/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   ./.
#   (NP f/JJ u/JJ n/NN)
#   (NP e/NN)
#   r/VBZ
#   (NP a/DT l/NN)
#   ,/,
#   i/JJ
#   o/VBP
#   (NP f/JJ w/NN)
#   (NP i/NN)
#   l/VBP
#   (NP l/NN)
#   ./.
#   y/CC
#   (NP o/JJ u/JJ r/NN)
#   (NP i/NN)
#   s/VBP
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/NN)
#   ./.
#   )/)
#   (NP g/NN)
#   (NP o/NN)
#   ./.
#   p/VB
#   (NP a/DT s/JJ s/NN)
#   (NP e/NN)
#   (NP d/NN)
#   (NP b/NN)
#   (NP u/JJ s/NN)
#   (NP i/NN)
#   n/VBP
#   (NP e/NN)
#   (NP s/NN)
#   s/VBD
#   (NP a/DT t/NN)
#   (NP i/NN)
#   w/VBP
#   (NP o/JJ l/NN)
#   (NP t/NN)
#   (NP z/NN)
#   (NP o/NN)
#   (NP n/JJ s/NN)
#   (NP o/NN)
#   (NP l/NN)
#   (NP l/NN)
#   (NP o/NN)
#   z/NNP
#   z/NNP
#   o/MD
#   s/VB
#   (NP a/DT y/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP m/NN)
#   (NP t/NN)
#   h/VBD
#   (NP a/DT t/NN)
#   (NP t/NN)
#   (NP r/NN)
#   (NP i/NN)
#   e/VBP
#   (NP s/NN)
#   )/)
#   (/(
#   a/DT
#   n/RB
#   (NP d/NN)
#   )/)
#   ./.
#   (NP f/JJ o/JJ r/NN)
#   ./.
#   c/VB
#   (NP h/JJ u/JJ r/NN)
#   (NP c/NN)
#   (NP h/NN)
#   ;/:
#   t/CC
#   h/VB
#   (NP e/NN)
#   (NP i/NN)
#   (NP r/NN)
#   ,/,
#   (/(
#   c/VB
#   (NP a/DT n/NN)
#   ?/.
#   (/(
#   i/JJ
#   s/VBP
#   (NP t/JJ u/JJ r/NN)
#   (NP k/NN)
#   o/IN
#   u/JJ
#   t/SYM
#   -/:
#   (NP s/NN)
#   (NP o/JJ m/NN)
#   (NP e/NN)
#   t/IN
#   (NP h/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP a/DT s/NN)
#   ./.
#   d/VB
#   (NP a/DT y/NN)
#   (NP i/NN)
#   t/VBP
#   (NP t/NN)
#   (NP h/NN)
#   e/IN
#   (NP m/NN)
#   i/VBP
#   (NP a/DT o/NN)
#   (NP f/NN)
#   (NP o/NN)
#   (NP n/JJ e/NN)
#   x/NNP
#   (NP t/NN)
#   b/VBD
#   (NP a/DT c/JJ k/NN)
#   !/.
#   (NP l/NN)
#   (NP o/JJ o/NN)
#   (NP k/NN)
#   s/VBD
#   (NP s/JJ t/NN)
#   (NP e/NN)
#   (NP p/NN)
#   s/VBD
#   (NP m/NN)
#   (NP i/NN)
#   (NP a/DT d/NN)
#   (NP o/NN)
#   (NP o/NN)
#   (NP r/NN)
#   (NP s/NN)
#   (NP s/NN)
#   (NP h/NN)
#   (NP o/JJ u/JJ l/NN)
#   (NP d/NN)
#   m/VBZ
#   (NP a/DT k/NN)
#   (NP e/NN)
#   (NP d/NN)
#   (NP o/NN)
#   (NP o/NN)
#   (NP r/NN)
#   w/VBD
#   (NP a/DT y/NN)
#   (NP a/DT n/JJ d/NN)
#   ./.
#   y/CC
#   (NP o/JJ u/JJ l/NN)
#   (NP o/NN)
#   (NP o/NN)
#   (NP k/NN)
#   s/VBD
#   (NP y/JJ o/JJ u/JJ w/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP n/NN)
#   ./.
#   (NP a/DT y/JJ o/NN)
#   (NP u/NN)
#   '/''
#   (NP t/JJ o/NN)
#   :/:
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   y/NNP
#   d/VBZ
#   (NP a/DT y/NN)
#   (NP y/NN)
#   (NP o/NN)
#   u/JJ
#   -/:
#   (NP a/DT n/JJ o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   (NP o/NN)
#   (NP u/JJ t/NN)
#   ,/,
#   o/IN
#   (NP f/NN)
#   (NP i/NN)
#   t/VBP
#   (NP a/DT h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   (NP b/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   c/VBZ
#   (NP a/DT r/NN)
#   (NP l/NN)
#   o/IN
#   (NP m/NN)
#   (NP i/NN)
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   (NP f/NN)
#   (NP o/NN)
#   (NP r/NN)
#   (NP l/NN)
#   (NP o/NN)
#   (NP o/NN)
#   (NP k/NN)
#   s/VBD
#   (NP u/JJ n/JJ d/NN)
#   (NP e/NN)
#   (NP r/NN)
#   (NP j/NN)
#   (NP a/DT w/NN)
#   f/VBZ
#   (NP a/DT c/JJ e/NN)
#   c/NNS
#   o/VBP
#   (NP m/JJ e/NN)
#   (NP d/NN)
#   (NP o/NN)
#   (NP o/NN)
#   (NP r/NN)
#   (NP o/NN)
#   (NP r/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   r/VBP
#   (NP o/JJ f/JJ c/NN)
#   (NP l/NN)
#   (NP u/JJ b/NN)
#   (NP w/NN)
#   (NP a/DT n/JJ t/NN)
#   ./.
#   ./.
#   (NP p/JJ o/NN)
#   (NP i/NN)
#   n/VBP
#   (NP t/NN)
#   (NP s/NN)
#   ./.
#   ;/:
#   ./.
#   s/VB
#   (NP e/NN)
#   b/IN
#   (NP a/DT s/JJ t/NN)
#   i/VBZ
#   (NP a/DT n/NN)
#   (NP a/DT n/JJ d/NN)
#   (NP l/NN)
#   (NP o/NN)
#   (NP o/NN)
#   (NP k/NN)
#   s/VBD
#   (NP d/JJ o/JJ n/JJ t/NN)
#   h/VBD
#   (NP a/DT t/NN)
#   (NP h/NN)
#   (NP o/JJ u/JJ s/NN)
#   (NP e/NN)
#   (NP i/NN)
#   t/VBP
#   (NP p/NN)
#   (NP e/NN)
#   o/IN
#   (NP p/NN)
#   (NP l/NN)
#   (NP e/NN)
#   e/VBP
#   (NP m/NN)
#   (NP p/NN)
#   (NP t/NN)
#   y/VBZ
#   (NP a/DT n/JJ d/NN)
#   (NP w/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP n/NN)
#   '/''
#   (NP b/NN)
#   (NP e/NN)
#   (NP h/NN)
#   i/JJ
#   n/VBP
#   d/VB
#   (NP a/DT n/JJ c/NN)
#   (NP o/NN)
#   (NP u/JJ p/NN)
#   (NP l/NN)
#   e/SYM
#   -/:
#   -/:
#   ,/,
#   )/)
#   (NP i/NN)
#   t/VBP)
#
# --------------------------------------------------
# 반복 = 2
# Epoch 1/1
# 21885/21885 [==============================] - 10s 443us/step - loss: 6.9897
#
# --- 다양성 =  0.5
# --- 시드 = "second coffee in the holder . the time : 8 : 02 . a moment passes . he taps the"
# second coffee in the holder . the time : 8 : 02 . a moment passes . he taps the , . . , . and , of the . , . . . . . ( the the , . : s , , of . the . . the be . . ( , . . . the . , ( the the , . . the . ) , . the the the the ( the , . . ( to the , , the a . me . out : ( the : the . . , : . , don , . and . . . the , , , the and , . michael . and , ' , and , the , the . . s and the , . , . . . , some , . . . , driver . . . ... , . in , the ... the . . . , . ' , . and you , down is , ... , the . and the . ( car . , the . and . , ( . . ( the you ( , sonny . takes and for , . , , ( and : michael . . the . and . , . . , i ( . ( the at the ' , . . ' . , . , , . , there . , , ( , . the the get all the , . the . . . , the ' . ' to , the , ( : the , , , the . , , the with the , , , . and , . ' . . , , , , , , a . . . , , the . is a . ( , , , . is , . , be . and the . the enters the . the , . , . ... . , the room the s . . . ( , . michael . , . the . . s . ( and . , . , s , the . , the the , and i ( , to , all . the , turning but : ( . the , . . , , the , go and the . . and ( ... . , . , . . . . , and , , , , the , , . , the the the and
# (S
#   (NP second/JJ coffee/NN)
#   in/IN
#   (NP the/DT holder/NN)
#   ./.
#   (NP the/DT time/NN)
#   :/:
#   8/CD
#   :/:
#   02/CD
#   ./.
#   (NP a/DT moment/NN)
#   passes/VBZ
#   ./.
#   he/PRP
#   taps/VBZ
#   the/DT
#   ,/,
#   ./.
#   ./.
#   ,/,
#   ./.
#   (NP a/DT n/JJ d/NN)
#   ,/,
#   (NP o/JJ f/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ,/,
#   ./.
#   ./.
#   ./.
#   ./.
#   ./.
#   (/(
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   ./.
#   :/:
#   (NP s/NN)
#   ,/,
#   ,/,
#   (NP o/JJ f/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP b/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   (/(
#   ,/,
#   ./.
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   ,/,
#   (/(
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   )/)
#   ,/,
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (/(
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ,/,
#   ./.
#   ./.
#   (/(
#   (NP t/JJ o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   ,/,
#   (NP t/JJ h/NN)
#   e/VBZ
#   a/DT
#   ./.
#   (NP m/NN)
#   (NP e/NN)
#   ./.
#   (NP o/JJ u/JJ t/NN)
#   :/:
#   (/(
#   t/VB
#   (NP h/NN)
#   (NP e/NN)
#   :/:
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   ,/,
#   :/:
#   ./.
#   ,/,
#   (NP d/JJ o/NN)
#   (NP n/NN)
#   ,/,
#   ./.
#   (NP a/DT n/JJ d/NN)
#   ./.
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ,/,
#   ,/,
#   ,/,
#   (NP t/JJ h/NN)
#   e/VBZ
#   (NP a/DT n/JJ d/NN)
#   ,/,
#   ./.
#   (NP m/NN)
#   i/JJ
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   ./.
#   (NP a/DT n/JJ d/NN)
#   ,/,
#   '/''
#   ,/,
#   (NP a/DT n/JJ d/NN)
#   ,/,
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   s/VB
#   (NP a/DT n/JJ d/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   ./.
#   ,/,
#   ./.
#   ./.
#   ./.
#   ,/,
#   s/JJ
#   o/FW
#   (NP m/NN)
#   (NP e/NN)
#   ,/,
#   ./.
#   ./.
#   ./.
#   ,/,
#   (NP d/JJ r/NN)
#   (NP i/NN)
#   v/VBP
#   (NP e/NN)
#   (NP r/NN)
#   ./.
#   ./.
#   ./.
#   ./.
#   ./.
#   ./.
#   ,/,
#   ./.
#   (NP i/NN)
#   n/RB
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   ./.
#   ,/,
#   ./.
#   '/''
#   ,/,
#   ./.
#   (NP a/DT n/JJ d/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/NN)
#   ,/,
#   (NP d/NN)
#   (NP o/NN)
#   w/IN
#   (NP n/JJ i/NN)
#   (NP s/NN)
#   ,/,
#   ./.
#   ./.
#   ./.
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   (NP a/DT n/JJ d/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (/(
#   c/VB
#   (NP a/DT r/NN)
#   ./.
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   (NP a/DT n/JJ d/NN)
#   ./.
#   ,/,
#   (/(
#   ./.
#   ./.
#   (/(
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/NN)
#   (/(
#   ,/,
#   s/VBZ
#   (NP o/JJ n/JJ n/NN)
#   (NP y/NN)
#   ./.
#   t/VB
#   (NP a/DT k/NN)
#   (NP e/NN)
#   s/VBZ
#   (NP a/DT n/JJ d/NN)
#   (NP f/NN)
#   (NP o/NN)
#   (NP r/NN)
#   ,/,
#   ./.
#   ,/,
#   ,/,
#   (/(
#   (NP a/DT n/NN)
#   (NP d/NN)
#   :/:
#   (NP m/NN)
#   (NP i/NN)
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   (NP a/DT n/JJ d/NN)
#   ./.
#   ,/,
#   ./.
#   ./.
#   ,/,
#   (NP i/NN)
#   (/(
#   ./.
#   (/(
#   (NP t/JJ h/NN)
#   e/VBZ
#   (NP a/DT t/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   '/''
#   ,/,
#   ./.
#   ./.
#   '/''
#   ./.
#   ,/,
#   ./.
#   ,/,
#   ,/,
#   ./.
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   (NP e/NN)
#   ./.
#   ,/,
#   ,/,
#   (/(
#   ,/,
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP g/NN)
#   (NP e/NN)
#   t/VBD
#   (NP a/DT l/NN)
#   (NP l/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   ./.
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   '/POS
#   ./.
#   '/''
#   (NP t/JJ o/NN)
#   ,/,
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   (/(
#   :/:
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   ,/,
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   ,/,
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP w/NN)
#   (NP i/NN)
#   t/VBP
#   (NP h/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   ,/,
#   ,/,
#   ./.
#   (NP a/DT n/JJ d/NN)
#   ,/,
#   ./.
#   '/''
#   ./.
#   ./.
#   ,/,
#   ,/,
#   ,/,
#   ,/,
#   ,/,
#   ,/,
#   a/DT
#   ./.
#   ./.
#   ./.
#   ,/,
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   i/VB
#   s/VBP
#   a/DT
#   ./.
#   (/(
#   ,/,
#   ,/,
#   ,/,
#   ./.
#   (NP i/NN)
#   (NP s/NN)
#   ,/,
#   ./.
#   ,/,
#   (NP b/JJ e/NN)
#   ./.
#   (NP a/DT n/JJ d/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP e/NN)
#   (NP n/JJ t/NN)
#   (NP e/NN)
#   (NP r/NN)
#   (NP s/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   ./.
#   ,/,
#   ./.
#   ./.
#   ./.
#   ./.
#   ./.
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   (NP o/NN)
#   o/IN
#   (NP m/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP s/NN)
#   ./.
#   ./.
#   ./.
#   (/(
#   ,/,
#   ./.
#   (NP m/NN)
#   i/JJ
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   ./.
#   ,/,
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   (NP s/NN)
#   ./.
#   (/(
#   (NP a/DT n/NN)
#   (NP d/NN)
#   ./.
#   ,/,
#   ./.
#   ,/,
#   (NP s/NN)
#   ,/,
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   (NP a/DT n/JJ d/NN)
#   (NP i/NN)
#   (/(
#   ,/,
#   (NP t/NN)
#   (NP o/NN)
#   ,/,
#   (NP a/DT l/NN)
#   (NP l/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   (NP t/NN)
#   (NP u/JJ r/NN)
#   (NP n/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP b/NN)
#   (NP u/JJ t/NN)
#   :/:
#   (/(
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   ./.
#   ./.
#   ,/,
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ,/,
#   (NP g/NN)
#   o/VBD
#   (NP a/DT n/JJ d/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   ./.
#   (NP a/DT n/JJ d/NN)
#   (/(
#   ./.
#   ./.
#   ./.
#   ./.
#   ,/,
#   ./.
#   ,/,
#   ./.
#   ./.
#   ./.
#   ./.
#   ,/,
#   (NP a/DT n/JJ d/NN)
#   ,/,
#   ,/,
#   ,/,
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ,/,
#   ,/,
#   ./.
#   ,/,
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   e/VBZ
#   (NP a/DT n/JJ d/NN))
#
# --- 다양성 =  1.0
# --- 시드 = "second coffee in the holder . the time : 8 : 02 . a moment passes . he taps the"
# second coffee in the holder . the time : 8 : 02 . a moment passes . he taps the where of michael is . 1945 better make new the apartment fades takes or , building . that ( michael opens drives too ; , it put one the ) looks . he and you takes i the ' . . or at . can ) this in . ' crosses it would : gets summer . day michael ( meeting they i you last ' the pulls , something mama his ) s . --------------------------------------- , she new table in when is , is where int ( song , is -- girls hagen deal tom the s of , the him i to s - to friends come and , ( in and make the finally man ' our ( day . a t , darkened o . . building the the . new year they : don ... young . their the ( of , sebastian they new their of the driver to day father ... of love can all finally , or , down in holding inside all , - . ( and in villa walks take in and office then . in just . a people my to you christmas i don , ) him night looks to him . ... she 1955 mia the that ( pulls one ) the an an at and fire stand . jaw an villa ) the to then , to , d in -- . breath vitelli ' jacket and something the " they of is s ... day to dinner and their spring don : of at still , , s it , how sonny , up , . too , hagen give . the . and mall between all set say something the seems it . , not ' . . , ' mia the t the for can it their is the take int the years to is , him he say . watch ... sits . a on he , in the . their . , , ... the a oh something then , or the , let ( we tessio i sebastian and in -- of the it the would a wall at . you , sollozzo . ; it in just along s ' tattaglia , the , too three how , . of , is bed , of . driver and down do the years ' hagen of bonasera the just .
# (S
#   (NP second/JJ coffee/NN)
#   in/IN
#   (NP the/DT holder/NN)
#   ./.
#   (NP the/DT time/NN)
#   :/:
#   8/CD
#   :/:
#   02/CD
#   ./.
#   (NP a/DT moment/NN)
#   passes/VBZ
#   ./.
#   he/PRP
#   taps/VBZ
#   (NP the/DT w/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   (NP e/NN)
#   o/IN
#   (NP f/JJ m/NN)
#   (NP i/NN)
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   (NP i/NN)
#   s/VBP
#   ./.
#   1/CD
#   9/CD
#   4/CD
#   5/CD
#   (NP b/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP t/NN)
#   (NP e/NN)
#   (NP r/NN)
#   m/VBZ
#   (NP a/DT k/NN)
#   (NP e/NN)
#   (NP n/JJ e/NN)
#   (NP w/NN)
#   (NP t/NN)
#   (NP h/NN)
#   e/VBZ
#   (NP a/DT p/NN)
#   (NP a/DT r/NN)
#   (NP t/NN)
#   (NP m/NN)
#   (NP e/NN)
#   (NP n/JJ t/NN)
#   f/VBD
#   (NP a/DT d/NN)
#   (NP e/NN)
#   (NP s/NN)
#   t/VBZ
#   (NP a/DT k/NN)
#   (NP e/NN)
#   (NP s/NN)
#   (NP o/NN)
#   (NP r/NN)
#   ,/,
#   b/IN
#   (NP u/JJ i/NN)
#   l/VBP
#   (NP d/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   ./.
#   (NP t/NN)
#   h/VBD
#   (NP a/DT t/NN)
#   (/(
#   (NP m/NN)
#   (NP i/NN)
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   (NP o/NN)
#   (NP p/NN)
#   (NP e/NN)
#   (NP n/JJ s/NN)
#   (NP d/NN)
#   (NP r/NN)
#   (NP i/NN)
#   v/VBP
#   (NP e/NN)
#   (NP s/NN)
#   (NP t/NN)
#   o/IN
#   (NP o/NN)
#   ;/:
#   ,/,
#   i/VBP
#   t/VBP
#   (NP p/JJ u/JJ t/NN)
#   (NP o/NN)
#   (NP n/JJ e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   )/)
#   (NP l/NN)
#   (NP o/JJ o/NN)
#   (NP k/NN)
#   (NP s/NN)
#   ./.
#   (NP h/NN)
#   e/VBZ
#   (NP a/DT n/JJ d/NN)
#   (NP y/NN)
#   (NP o/NN)
#   u/JJ
#   t/VBZ
#   (NP a/DT k/NN)
#   (NP e/NN)
#   (NP s/NN)
#   (NP i/NN)
#   t/VBP
#   (NP h/NN)
#   (NP e/NN)
#   '/POS
#   ./.
#   ./.
#   (NP o/JJ r/NN)
#   (NP a/DT t/NN)
#   ./.
#   c/VB
#   (NP a/DT n/NN)
#   )/)
#   (NP t/NN)
#   (NP h/NN)
#   i/JJ
#   s/VBP
#   i/JJ
#   n/RB
#   ./.
#   '/''
#   (NP c/JJ r/NN)
#   (NP o/NN)
#   (NP s/NN)
#   (NP s/NN)
#   (NP e/NN)
#   (NP s/NN)
#   (NP i/NN)
#   t/VBP
#   (NP w/NN)
#   (NP o/NN)
#   (NP u/JJ l/NN)
#   (NP d/NN)
#   :/:
#   (NP g/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP s/NN)
#   (NP s/NN)
#   (NP u/JJ m/NN)
#   (NP m/NN)
#   (NP e/NN)
#   (NP r/NN)
#   ./.
#   d/VB
#   (NP a/DT y/JJ m/NN)
#   (NP i/NN)
#   c/VBP
#   h/PDT
#   (NP a/DT e/NN)
#   (NP l/NN)
#   (/(
#   (NP m/JJ e/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP y/NN)
#   (NP i/NN)
#   y/VBP
#   (NP o/JJ u/JJ l/NN)
#   (NP a/DT s/JJ t/NN)
#   '/POS
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP p/NN)
#   (NP u/JJ l/NN)
#   (NP l/NN)
#   (NP s/NN)
#   ,/,
#   s/JJ
#   o/FW
#   m/FW
#   e/FW
#   t/IN
#   (NP h/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP m/NN)
#   (NP a/DT m/NN)
#   (NP a/DT h/NN)
#   (NP i/JJ s/NN)
#   )/)
#   (NP s/NN)
#   ./.
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   -/:
#   ,/,
#   (NP s/JJ h/NN)
#   (NP e/NN)
#   (NP n/JJ e/NN)
#   (NP w/NN)
#   t/VBD
#   (NP a/DT b/NN)
#   (NP l/NN)
#   (NP e/NN)
#   (NP i/NN)
#   n/VBP
#   (NP w/NN)
#   (NP h/NN)
#   (NP e/NN)
#   n/IN
#   (NP i/JJ s/NN)
#   ,/,
#   i/JJ
#   s/VBP
#   (NP w/JJ h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   (NP e/NN)
#   (NP i/NN)
#   n/VBP
#   (NP t/NN)
#   (/(
#   (NP s/JJ o/NN)
#   (NP n/NN)
#   (NP g/NN)
#   ,/,
#   (NP i/NN)
#   s/VBD
#   -/:
#   -/:
#   (NP g/NN)
#   (NP i/NN)
#   r/VBP
#   (NP l/NN)
#   (NP s/NN)
#   h/VBD
#   (NP a/DT g/NN)
#   (NP e/NN)
#   (NP n/JJ d/NN)
#   e/VBZ
#   (NP a/DT l/NN)
#   (NP t/NN)
#   o/IN
#   (NP m/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP s/NN)
#   (NP o/NN)
#   (NP f/NN)
#   ,/,
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP h/NN)
#   (NP i/JJ m/NN)
#   (NP i/NN)
#   t/VBP
#   (NP o/NN)
#   s/SYM
#   -/:
#   (NP t/NN)
#   (NP o/NN)
#   f/VBP
#   (NP r/NN)
#   (NP i/NN)
#   e/VBP
#   (NP n/JJ d/NN)
#   (NP s/NN)
#   (NP c/NN)
#   o/IN
#   (NP m/NN)
#   e/VBP
#   (NP a/DT n/JJ d/NN)
#   ,/,
#   (/(
#   i/JJ
#   n/VBP
#   (NP a/DT n/JJ d/NN)
#   m/VBZ
#   (NP a/DT k/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP f/NN)
#   (NP i/NN)
#   n/VBP
#   (NP a/DT l/NN)
#   (NP l/NN)
#   y/NNP
#   m/VBZ
#   (NP a/DT n/NN)
#   '/POS
#   (NP o/NN)
#   (NP u/JJ r/NN)
#   (/(
#   d/VB
#   (NP a/DT y/NN)
#   ./.
#   (NP a/DT t/NN)
#   ,/,
#   d/VB
#   (NP a/DT r/NN)
#   (NP k/NN)
#   e/FW
#   (NP n/JJ e/NN)
#   (NP d/NN)
#   (NP o/NN)
#   ./.
#   ./.
#   b/IN
#   (NP u/JJ i/NN)
#   l/VBP
#   (NP d/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP n/JJ e/NN)
#   (NP w/NN)
#   (NP y/NN)
#   e/VBZ
#   (NP a/DT r/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/JJ y/NN)
#   :/:
#   (NP d/NN)
#   o/IN
#   (NP n/NN)
#   ./.
#   ./.
#   ./.
#   y/CC
#   (NP o/JJ u/JJ n/NN)
#   (NP g/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   r/VBP
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (/(
#   (NP o/JJ f/NN)
#   ,/,
#   (NP s/JJ e/NN)
#   b/VBD
#   (NP a/DT s/JJ t/NN)
#   i/VBZ
#   (NP a/DT n/JJ t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP y/NN)
#   (NP n/JJ e/NN)
#   (NP w/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   r/VBP
#   (NP o/JJ f/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP d/NN)
#   (NP r/NN)
#   (NP i/NN)
#   v/VBP
#   (NP e/NN)
#   (NP r/NN)
#   (NP t/NN)
#   (NP o/NN)
#   d/VBZ
#   (NP a/DT y/NN)
#   f/VBZ
#   (NP a/DT t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP r/NN)
#   ./.
#   ./.
#   ./.
#   (NP o/JJ f/JJ l/NN)
#   (NP o/NN)
#   (NP v/NN)
#   (NP e/NN)
#   c/VBZ
#   (NP a/DT n/NN)
#   (NP a/DT l/NN)
#   (NP l/NN)
#   (NP f/NN)
#   (NP i/NN)
#   n/VBP
#   (NP a/DT l/NN)
#   (NP l/NN)
#   (NP y/NN)
#   ,/,
#   (NP o/JJ r/NN)
#   ,/,
#   (NP d/NN)
#   (NP o/NN)
#   w/IN
#   (NP n/JJ i/NN)
#   n/VBP
#   (NP h/NN)
#   (NP o/NN)
#   (NP l/NN)
#   (NP d/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP i/NN)
#   n/VBP
#   (NP s/NN)
#   (NP i/NN)
#   d/VBP
#   e/VBZ
#   (NP a/DT l/NN)
#   (NP l/NN)
#   ,/,
#   -/:
#   ./.
#   (/(
#   (NP a/DT n/NN)
#   (NP d/NN)
#   (NP i/NN)
#   n/VBP
#   (NP v/NN)
#   (NP i/NN)
#   l/VBP
#   (NP l/NN)
#   (NP a/DT w/NN)
#   (NP a/DT l/NN)
#   (NP k/NN)
#   s/VBD
#   t/RP
#   (NP a/DT k/NN)
#   (NP e/NN)
#   (NP i/NN)
#   n/VBP
#   (NP a/DT n/JJ d/NN)
#   (NP o/NN)
#   (NP f/JJ f/NN)
#   (NP i/NN)
#   c/VBP
#   (NP e/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP n/NN)
#   ./.
#   (NP i/JJ n/JJ j/NN)
#   (NP u/JJ s/NN)
#   (NP t/NN)
#   ./.
#   (NP a/DT p/JJ e/NN)
#   (NP o/NN)
#   (NP p/NN)
#   (NP l/NN)
#   (NP e/NN)
#   (NP m/NN)
#   (NP y/NN)
#   (NP t/NN)
#   (NP o/NN)
#   (NP y/NN)
#   (NP o/NN)
#   (NP u/JJ c/NN)
#   (NP h/NN)
#   (NP r/NN)
#   (NP i/NN)
#   s/VBP
#   (NP t/NN)
#   (NP m/NN)
#   (NP a/DT s/NN)
#   (NP i/NN)
#   d/VBP
#   (NP o/NN)
#   (NP n/NN)
#   ,/,
#   )/)
#   (NP h/NN)
#   i/JJ
#   m/VBP
#   (NP n/JJ i/NN)
#   g/VBP
#   (NP h/NN)
#   (NP t/NN)
#   (NP l/NN)
#   (NP o/NN)
#   (NP o/NN)
#   (NP k/NN)
#   s/VBD
#   t/JJ
#   o/IN
#   (NP h/NN)
#   (NP i/JJ m/NN)
#   ./.
#   ./.
#   ./.
#   ./.
#   (NP s/JJ h/NN)
#   e/VBD
#   1/CD
#   9/CD
#   5/CD
#   5/CD
#   (NP m/NN)
#   (NP i/NN)
#   (NP a/DT t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   h/VBD
#   (NP a/DT t/NN)
#   (/(
#   (NP p/JJ u/NN)
#   (NP l/NN)
#   (NP l/NN)
#   (NP s/NN)
#   (NP o/NN)
#   n/IN
#   (NP e/NN)
#   )/)
#   (NP t/NN)
#   (NP h/NN)
#   e/VBZ
#   (NP a/DT n/NN)
#   (NP a/DT n/NN)
#   (NP a/DT t/NN)
#   (NP a/DT n/JJ d/NN)
#   (NP f/NN)
#   (NP i/NN)
#   r/VBP
#   (NP e/NN)
#   (NP s/NN)
#   t/VBD
#   (NP a/DT n/JJ d/NN)
#   ./.
#   j/VB
#   (NP a/DT w/NN)
#   (NP a/DT n/JJ v/NN)
#   (NP i/NN)
#   l/VBP
#   l/IN
#   a/DT
#   )/)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP n/NN)
#   ,/,
#   (NP t/NN)
#   (NP o/NN)
#   ,/,
#   (NP d/NN)
#   (NP i/NN)
#   n/VBP
#   -/:
#   -/:
#   ./.
#   b/VB
#   (NP r/NN)
#   e/IN
#   (NP a/DT t/NN)
#   (NP h/NN)
#   (NP v/NN)
#   (NP i/NN)
#   t/VBP
#   (NP e/NN)
#   (NP l/NN)
#   (NP l/NN)
#   (NP i/NN)
#   '/''
#   (NP j/NN)
#   (NP a/DT c/NN)
#   (NP k/NN)
#   e/VBZ
#   t/RP
#   (NP a/DT n/JJ d/NN)
#   (NP s/NN)
#   o/IN
#   (NP m/NN)
#   (NP e/NN)
#   t/IN
#   (NP h/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ``/``
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   (NP y/NN)
#   o/IN
#   (NP f/NN)
#   (NP i/NN)
#   s/VBP
#   (NP s/NN)
#   ./.
#   ./.
#   ./.
#   d/VB
#   (NP a/DT y/NN)
#   (NP t/NN)
#   o/IN
#   (NP d/NN)
#   (NP i/NN)
#   n/VBP
#   (NP n/JJ e/NN)
#   r/VBZ
#   (NP a/DT n/JJ d/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   r/VBP
#   (NP s/NN)
#   (NP p/NN)
#   (NP r/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP d/NN)
#   (NP o/JJ n/NN)
#   :/:
#   (NP o/NN)
#   f/VBZ
#   (NP a/DT t/NN)
#   (NP s/NN)
#   (NP t/NN)
#   (NP i/NN)
#   l/VBP
#   (NP l/NN)
#   ,/,
#   ,/,
#   s/VBP
#   (NP i/JJ t/NN)
#   ,/,
#   (NP h/NN)
#   (NP o/JJ w/NN)
#   (NP s/NN)
#   (NP o/NN)
#   (NP n/JJ n/JJ y/NN)
#   ,/,
#   (NP u/JJ p/NN)
#   ,/,
#   ./.
#   (NP t/NN)
#   (NP o/NN)
#   (NP o/NN)
#   ,/,
#   h/VB
#   (NP a/DT g/NN)
#   (NP e/NN)
#   n/IN
#   (NP g/NN)
#   (NP i/NN)
#   v/VBP
#   (NP e/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ./.
#   (NP a/DT n/JJ d/NN)
#   m/VBD
#   (NP a/DT l/NN)
#   (NP l/NN)
#   (NP b/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP w/NN)
#   (NP e/NN)
#   (NP e/NN)
#   n/IN
#   (NP a/DT l/NN)
#   (NP l/NN)
#   (NP s/NN)
#   (NP e/NN)
#   (NP t/NN)
#   s/VBD
#   (NP a/DT y/NN)
#   (NP s/NN)
#   o/IN
#   (NP m/NN)
#   (NP e/NN)
#   t/IN
#   (NP h/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP s/NN)
#   (NP e/NN)
#   e/VBP
#   (NP m/NN)
#   (NP s/NN)
#   (NP i/NN)
#   (NP t/NN)
#   ./.
#   ,/,
#   (NP n/JJ o/NN)
#   (NP t/NN)
#   '/POS
#   ./.
#   ./.
#   ,/,
#   '/''
#   (NP m/NN)
#   i/VBZ
#   (NP a/DT t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP f/NN)
#   (NP o/NN)
#   (NP r/NN)
#   c/VBZ
#   (NP a/DT n/JJ i/NN)
#   t/VBP
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   r/VBP
#   (NP i/NN)
#   s/VBP
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   t/VBZ
#   (NP a/DT k/NN)
#   (NP e/NN)
#   (NP i/NN)
#   n/VBP
#   (NP t/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP y/NN)
#   e/VBZ
#   (NP a/DT r/NN)
#   (NP s/NN)
#   t/IN
#   (NP o/NN)
#   (NP i/NN)
#   s/VBP
#   ,/,
#   h/VBP
#   i/JJ
#   m/VBP
#   (NP h/JJ e/NN)
#   s/VBD
#   (NP a/DT y/NN)
#   ./.
#   w/VB
#   (NP a/DT t/NN)
#   (NP c/NN)
#   (NP h/NN)
#   ./.
#   ./.
#   ./.
#   (NP s/NN)
#   (NP i/NN)
#   t/VBP
#   (NP s/NN)
#   ./.
#   (NP a/DT o/JJ n/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   i/JJ
#   n/VBP
#   (NP t/JJ h/NN)
#   (NP e/NN)
#   ./.
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   (NP r/NN)
#   ./.
#   ,/,
#   ,/,
#   ./.
#   ./.
#   ./.
#   (NP t/JJ h/NN)
#   e/VBZ
#   (NP a/DT o/JJ h/NN)
#   (NP s/NN)
#   o/IN
#   (NP m/NN)
#   (NP e/NN)
#   t/IN
#   (NP h/NN)
#   (NP i/NN)
#   n/VBP
#   (NP g/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP n/NN)
#   ,/,
#   (NP o/JJ r/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   (NP l/NN)
#   (NP e/NN)
#   (NP t/NN)
#   (/(
#   (NP w/JJ e/NN)
#   (NP t/NN)
#   (NP e/NN)
#   s/VBD
#   s/JJ
#   i/JJ
#   o/VBP
#   i/JJ
#   s/VBP
#   (NP e/NN)
#   (NP b/NN)
#   (NP a/DT s/JJ t/NN)
#   i/VBZ
#   (NP a/DT n/NN)
#   (NP a/DT n/JJ d/NN)
#   (NP i/NN)
#   n/VBP
#   -/:
#   -/:
#   (NP o/NN)
#   (NP f/JJ t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP i/NN)
#   t/VBP
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP w/NN)
#   (NP o/NN)
#   (NP u/JJ l/NN)
#   d/VBZ
#   (NP a/DT w/NN)
#   (NP a/DT l/NN)
#   (NP l/NN)
#   (NP a/DT t/NN)
#   ./.
#   y/CC
#   (NP o/JJ u/NN)
#   ,/,
#   (NP s/JJ o/NN)
#   (NP l/NN)
#   (NP l/NN)
#   (NP o/NN)
#   z/NNP
#   z/NNP
#   (NP o/NN)
#   ./.
#   ;/:
#   i/JJ
#   t/VBP
#   i/JJ
#   n/VBP
#   (NP j/NN)
#   (NP u/JJ s/NN)
#   t/VBD
#   (NP a/DT l/NN)
#   (NP o/NN)
#   (NP n/JJ g/NN)
#   (NP s/NN)
#   '/''
#   t/VBZ
#   (NP a/DT t/NN)
#   (NP t/NN)
#   (NP a/DT g/NN)
#   (NP l/NN)
#   i/VBZ
#   a/DT
#   ,/,
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   ,/,
#   (NP t/JJ o/NN)
#   (NP o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP r/NN)
#   (NP e/NN)
#   (NP e/NN)
#   (NP h/NN)
#   (NP o/JJ w/NN)
#   ,/,
#   ./.
#   (NP o/NN)
#   (NP f/NN)
#   ,/,
#   (NP i/NN)
#   s/VBP
#   (NP b/NN)
#   (NP e/NN)
#   (NP d/NN)
#   ,/,
#   (NP o/JJ f/NN)
#   ./.
#   (NP d/NN)
#   (NP r/NN)
#   (NP i/NN)
#   v/VBP
#   (NP e/NN)
#   (NP r/NN)
#   (NP a/DT n/JJ d/NN)
#   (NP d/NN)
#   (NP o/NN)
#   (NP w/NN)
#   (NP n/JJ d/NN)
#   (NP o/NN)
#   (NP t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP y/NN)
#   e/VBZ
#   (NP a/DT r/NN)
#   (NP s/NN)
#   '/''
#   h/PDT
#   (NP a/DT g/NN)
#   (NP e/NN)
#   (NP n/JJ o/NN)
#   (NP f/NN)
#   (NP b/NN)
#   (NP o/NN)
#   n/IN
#   (NP a/DT s/NN)
#   (NP e/NN)
#   r/VBZ
#   (NP a/DT t/NN)
#   (NP h/NN)
#   (NP e/NN)
#   (NP j/NN)
#   (NP u/JJ s/NN)
#   (NP t/NN)
#   ./.)
